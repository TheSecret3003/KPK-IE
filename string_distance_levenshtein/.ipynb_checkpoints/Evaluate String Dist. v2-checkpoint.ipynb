# %%
import pandas as pd
import numpy as np
from get_similar_entity import get_similar_entity
from evaluation import clean_test_df, get_similar_entities_lev_v2

# %% [markdown]
# ## Prep test data
# Test data: distinct nama_instansi penerima dan pemberi from Tabel ai2022

# %%
test_data = pd.read_csv('./eval/test_data/distinct_instansi_ai_table.csv')

# %%
test_data.head()
# Out:
#               nama_instansi
# 0       Kementerian Kominfo
# 1                tidak tahu
# 2  PT Maybank Indonesia Tbk
# 3                   Rekanan
# 4              Kemko Marves

# %%
test_data = clean_test_df(test_data)

# %%
test_data.head()
# Out:
#               nama_instansi
# 0       kementerian kominfo
# 1                tidak tahu
# 2  pt maybank indonesia tbk
# 3                   rekanan
# 4              kemko marves

# %% [markdown]
# ## Predictions

# %%
predictions = get_similar_entities_lev_v2(test_data, reference_version='v2')

# %%
predictions.to_csv('./eval/automatically_labeled.csv')

# %%
predictions.head()
# Out:
#               nama_instansi                                    candidates
# 0       kementerian kominfo                                       kominfo
# 1                tidak tahu  Bukan instansi BUMN, Kementerian, Pemerintah
# 2  pt maybank indonesia tbk                                        pt bni
# 3                   rekanan  Bukan instansi BUMN, Kementerian, Pemerintah
# 4              kemko marves  Bukan instansi BUMN, Kementerian, Pemerintah

# %%
predictions.groupby('candidates').count()
# Out:
#                                               nama_instansi
# candidates
# Bukan instansi BUMN, Kementerian, Pemerintah           1181
# anggota dpr                                               5
# anri                                                      1
# arsip nasional republik indonesia anri                    1
# asdp indonesia                                            1
# ...                                                     ...
# skk migas                                                 7
# superintending company of indonesia                       1
# telkom                                                    1
# tni angkatan udara                                        2
# virama karya                                              1
#
# [561 rows x 1 columns]

# %% [markdown]
# ## Clean labeled data

# %%
train = pd.read_csv('../indexing/data/splitted_data/v2/train.csv')
val = pd.read_csv('../indexing/data/splitted_data/v2/val.csv')
test = pd.read_csv('../indexing/data/splitted_data/v2/test.csv')

# %%
df_all = pd.concat([train,val,test])

# %%
df_all
# Out:
#                                      instansi status  \
# 0         lembaga pembiayaan ekspor indonesia    yes
# 1         lembaga pembiayaan ekspor indonesia    yes
# 2         lembaga pembiayaan ekspor indonesia    yes
# 3         lembaga pembiayaan ekspor indonesia    yes
# 4         lembaga pembiayaan ekspor indonesia     no
# ..                                        ...    ...
# 907                              pt indofarma    yes
# 908                              pt indofarma     no
# 909   pt kereta api indonesia (persero) (kai)     no
# 910  pt dok dan perkapalan surabaya (persero)     no
# 911  pt dok dan perkapalan surabaya (persero)     no
#
#                        reference
# 0      lembaga pembiayaan ekspor
# 1                           lpei
# 2       lembaga ekspor indonesia
# 3    pembiayaan ekspor indonesia
# 4           pembiayaan indonesia
# ..                           ...
# 907                    indofarma
# 908                          igm
# 909                   kereta api
# 910                pt perkapalan
# 911                       pt dok
#
# [4345 rows x 3 columns]

# %% [markdown]
# Clean the data

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all['cln_instansi'] = df_all['instansi'].str.replace('/', ' ')
df_all['cln_instansi'] = df_all['cln_instansi'].str.replace('[^\w\s]','',regex=True)

# %%
df_all['cln_reference'] = df_all['reference'].str.replace('/', ' ')
df_all['cln_reference'] = df_all['cln_reference'].str.replace('[^\w\s]','',regex=True)

# %%
df_all = df_all.drop(['reference', 'instansi'], axis=1)

# %%
df_all = df_all.rename(columns={'cln_reference':'reference', 'cln_instansi':'instansi'})

# %%
df_all
# Out:
#      status                                instansi  \
# 0       yes     lembaga pembiayaan ekspor indonesia
# 1       yes     lembaga pembiayaan ekspor indonesia
# 2       yes     lembaga pembiayaan ekspor indonesia
# 3       yes     lembaga pembiayaan ekspor indonesia
# 4        no     lembaga pembiayaan ekspor indonesia
# ...     ...                                     ...
# 4340    yes                            pt indofarma
# 4341     no                            pt indofarma
# 4342     no     pt kereta api indonesia persero kai
# 4343     no  pt dok dan perkapalan surabaya persero
# 4344     no  pt dok dan perkapalan surabaya persero
#
#                         reference
# 0       lembaga pembiayaan ekspor
# 1                            lpei
# 2        lembaga ekspor indonesia
# 3     pembiayaan ekspor indonesia
# 4            pembiayaan indonesia
# ...                           ...
# 4340                    indofarma
# 4341                          igm
# 4342                   kereta api
# 4343                pt perkapalan
# 4344                       pt dok
#
# [4345 rows x 3 columns]

# %%
def get_true_refs(nama_instansi):
    """
    Function to get true references of given nama_instansi
    """
    try:
        official_instansi = df_all[(df_all['reference']==nama_instansi) & 
                                   (df_all['status']=='yes')]['instansi'].values[0]
    except:
        official_instansi = df_all[df_all['instansi']==nama_instansi]['instansi'].values[0]
    
    true_references = df_all[(df_all['instansi']==official_instansi)
                        & (df_all['status']=='yes')]['reference'].values
    
    true_refs = []
    for i in true_references:
        true_refs.append(i)

    true_refs.append(official_instansi)

    return true_refs

# %%
get_true_refs('kominfo')
# Out:
# ['kementerian komunikasi',
#  'kementerian informatika',
#  'kominfo',
#  'kementerian komunikasi dan informatika']

# %% [markdown]
# ## Analysis

# %%
predictions = pd.read_csv('./eval/automatically_labeled.csv')

# %%
predictions
# Out:
#       Unnamed: 0             nama_instansi  \
# 0              0       kementerian kominfo
# 1              1                tidak tahu
# 2              2  pt maybank indonesia tbk
# 3              3                   rekanan
# 4              4              kemko marves
# ...          ...                       ...
# 2155        2156    pt cahaya maha pertiwi
# 2156        2157            pemkab sintang
# 2157        2158                desa ginuk
# 2158        2159     direktur utama pt bni
# 2159        2160   tidak diketahui pelapor
#
#                                         candidates
# 0                                          kominfo
# 1     Bukan instansi BUMN, Kementerian, Pemerintah
# 2                                           pt bni
# 3     Bukan instansi BUMN, Kementerian, Pemerintah
# 4     Bukan instansi BUMN, Kementerian, Pemerintah
# ...                                            ...
# 2155                                        pt pii
# 2156                                pemkab sintang
# 2157  Bukan instansi BUMN, Kementerian, Pemerintah
# 2158                         direktur utama pt bni
# 2159  Bukan instansi BUMN, Kementerian, Pemerintah
#
# [2160 rows x 3 columns]

# %%
true_refs = []
status = []

# %%
for index, row in predictions.iterrows():
    nama_inst = row[['candidates']].values[0]
    if nama_inst == 'Bukan instansi BUMN, Kementerian, Pemerintah':
        true_refs.append([])
        status.append('yes')
    else:
        true_ref = get_true_refs(nama_inst)
        true_refs.append(true_ref)
        test_instansi = row[['nama_instansi']].values[0]
        if test_instansi in true_ref:
            status.append('yes')
        else:
            status.append('no')

# %%
predictions['true_references'] = true_refs
predictions['status'] = status

# %%
predictions
# Out:
#       Unnamed: 0             nama_instansi  \
# 0              0       kementerian kominfo
# 1              1                tidak tahu
# 2              2  pt maybank indonesia tbk
# 3              3                   rekanan
# 4              4              kemko marves
# ...          ...                       ...
# 2155        2156    pt cahaya maha pertiwi
# 2156        2157            pemkab sintang
# 2157        2158                desa ginuk
# 2158        2159     direktur utama pt bni
# 2159        2160   tidak diketahui pelapor
#
#                                         candidates  \
# 0                                          kominfo
# 1     Bukan instansi BUMN, Kementerian, Pemerintah
# 2                                           pt bni
# 3     Bukan instansi BUMN, Kementerian, Pemerintah
# 4     Bukan instansi BUMN, Kementerian, Pemerintah
# ...                                            ...
# 2155                                        pt pii
# 2156                                pemkab sintang
# 2157  Bukan instansi BUMN, Kementerian, Pemerintah
# 2158                         direktur utama pt bni
# 2159  Bukan instansi BUMN, Kementerian, Pemerintah
#
#                                         true_references status
# 0     [kementerian komunikasi, kementerian informati...     no
# 1                                                    []    yes
# 2     [pt bni, bni, bank negara indonesia, bank bni,...     no
# 3                                                    []    yes
# 4                                                    []    yes
# ...                                                 ...    ...
# 2155  [pt penjaminan infrastruktur indonesia, penjam...     no
# 2156  [pemkab sintang, pemerintah sintang, pemerinta...    yes
# 2157                                                 []    yes
# 2158  [pt bni, bni, bank negara indonesia, bank bni,...    yes
# 2159                                                 []    yes
#
# [2160 rows x 5 columns]

# %%
predictions.groupby('status').count()
# Out:
#         Unnamed: 0  nama_instansi  candidates  true_references
# status
# no             601            601         601              601
# yes           1559           1558        1559             1559

# %%
predictions.isnull().sum()
# Out:
# Unnamed: 0         0
# nama_instansi      1
# candidates         0
# true_references    0
# status             0
# dtype: int64

# %%
test_data = pd.read_csv('./eval/test_data/distinct_instansi_ai_table.csv')

# %%
test_data.isnull().sum()
# Out:
# nama_instansi    1
# dtype: int64

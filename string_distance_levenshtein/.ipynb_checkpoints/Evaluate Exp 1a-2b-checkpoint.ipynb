# %%
import pandas as pd
import numpy as np
from get_similar_entity import get_similar_entity
from evaluation import clean_test_df, get_similar_entity_1a

# %% [markdown]
# ## Prep test data

# %%
test_data = pd.read_csv('./eval/test_data/distinct_instansi_ai_table.csv')

# %%
test_data.head()
# Out:
#               nama_instansi
# 0       Kementerian Kominfo
# 1                tidak tahu
# 2  PT Maybank Indonesia Tbk
# 3                   Rekanan
# 4              Kemko Marves

# %%
test_data2 = test_data[['nama_instansi']]

# %%
# test_data2 = test_data2.rename(columns={'reference': 'nama_instansi'})

# %%
test_data2
# Out:
#                  nama_instansi
# 0          Kementerian Kominfo
# 1                   tidak tahu
# 2     PT Maybank Indonesia Tbk
# 3                      Rekanan
# 4                 Kemko Marves
# ...                        ...
# 2239    PT Cahaya Maha Pertiwi
# 2240            Pemkab Sintang
# 2241                Desa Ginuk
# 2242     Direktur Utama PT BNI
# 2243   Tidak diketahui pelapor
#
# [2244 rows x 1 columns]

# %%
test_data2 = clean_test_df(test_data2)

# %%
test_data2.head()
# Out:
#               nama_instansi
# 0       kementerian kominfo
# 1                tidak tahu
# 2  pt maybank indonesia tbk
# 3                   rekanan
# 4              kemko marves

# %%
test_data2.isnull().sum()
# Out:
# nama_instansi    0
# dtype: int64

# %% [markdown]
# duplicate removed

# %%
test_data2.shape
# Out:
# (2160, 1)

# %%
test_data2
# Out:
#                  nama_instansi
# 0          kementerian kominfo
# 1                   tidak tahu
# 2     pt maybank indonesia tbk
# 3                      rekanan
# 4                 kemko marves
# ...                        ...
# 2156    pt cahaya maha pertiwi
# 2157            pemkab sintang
# 2158                desa ginuk
# 2159     direktur utama pt bni
# 2160   tidak diketahui pelapor
#
# [2160 rows x 1 columns]

# %% [markdown]
# ## Predictions

# %%
predictions = get_similar_entity_1a(test_data2, reference_version='v2')
# Out:
# processing index 0: kementerian kominfo
# processing index 1: tidak tahu
# processing index 2: pt maybank indonesia tbk
# processing index 3: rekanan
# processing index 4: kemko marves
# processing index 5: smk negeri 1 jogonalan
# processing index 6: kantor pelayanan pajak pratama medan barat
# processing index 7: grab
# processing index 8: pt sawit sumbermas sarana tbk
# processing index 9: pt nusa niaga perkasa
# processing index 10: pemerintah kota kotamobagu
# processing index 11: lanal gorontalo
# processing index 12: pemerintah kabupaten ciamis
# processing index 13: pemerintah kabupaten sumba tengah ntt
# processing index 14: asuransi jiwa sinarmas
# processing index 15: lapas kelas iia cilegon
# processing index 16: masyarakat
# processing index 17: pt yaza pratama
# processing index 18: yayasan reef check indonesia
# processing index 19: kencana sakti
# processing index 20: sma raudlatul ulum 2 kubu raya
# processing index 21: pt indofood fortuna makmur
# processing index 22: lembaga pembiayaan ekspor indonesia
# processing index 23: bank bni cabang perguruan tinggi bandung
# processing index 24: pt citra riantara sejahtera
# processing index 25: kanwil kemenag jawa tengah
# processing index 26: pt intercons
# processing index 27: kontraktor listrik
# processing index 28: kantor atr   bpn kota salatiga
# processing index 29: pemerintah kabupaten kudus
# processing index 30: distributor pupuk bersubsidi
# processing index 31: advokat kuasa hukum
# processing index 32: universitas islam batik
# processing index 33: direktur cv edlin lestari mandiri
# processing index 34: dinas koperasi dan ukm kabupaten sleman
# processing index 35: perhimpunan pedagang surat utang
# processing index 36: mahkamah
# processing index 37: pt asuransi jasa indonesia persero
# processing index 38: hotel vasa dan hotel bumi
# processing index 39: dinas pendidikan sekolah smp sd
# processing index 40: bank syariah indonesia malang
# processing index 41: kementerian kesehatan
# processing index 42: perusahaan renis jaya
# processing index 43: pt candi arta
# processing index 44: founder astronacci  pegawai swasta
# processing index 45: roseana widyanti sh mkn
# processing index 46: think artha
# processing index 47: laboratorium valid
# processing index 48: ksp kospinjasa dan ksp pangestu
# processing index 49: badan narkotika nasional
# processing index 50: man 2 kampar
# processing index 51: nasabah bank mandiri pemilik toko parfum
# processing index 52: babk bjb cabang karawang
# processing index 53: pt rianda usaha mandiri
# processing index 54: direktur jakarta convention center
# processing index 55: tidak diketahui namun diduga nasabah bni
# processing index 56: pt kordon putra sinerga
# processing index 57: garuda food
# processing index 58: cv hotma sinar surya
# processing index 59: pt garuda indonesia
# processing index 60: umum
# processing index 61: ketua dprd kabupaten malinau
# processing index 62: pt bulog cabang surakarta
# processing index 63: loka pom di loka rejang lebong dan bpom di bengkulu
# processing index 64: kementerian keuangan bangladesh
# processing index 65: pt semen jakarta
# processing index 66: bank indonesia bank sentral republik indonesia
# processing index 67: universitas hamzanwadi lombok ntb
# processing index 68: pemerintah kabupaten grobogan
# processing index 69: toko muhanah
# processing index 70: rs banyumanik
# processing index 71: kementerian pupr
# processing index 72: kgi sekuritas
# processing index 73: pt hidup tujuh lautan
# processing index 74: hotel horison
# processing index 75: pt nusa biru abadi
# processing index 76: bank mandiri medan
# processing index 77: pemerintah kabupaten pemalang
# processing index 78: pt lisna syifa prima padang
# processing index 79: ptpn xii
# processing index 80: polres kabtapanuli selatan
# processing index 81: uptd kab bima
# processing index 82: fave hotel tuban
# processing index 83: dinas kesehatan sumba timur
# processing index 84: el royal hotel
# processing index 85: camat kecamatan mulak sebingkai
# processing index 86: smk pasundan 1
# processing index 87: wajib pajak individu
# processing index 88: badan pelindungan pekerja migran indonesia
# processing index 89: anggota dprd fraksi ppp
# processing index 90: kkp kelas iii bitung
# processing index 91: terlampir
# processing index 92: desa mekarharja
# processing index 93: pt artha teknik abadi
# processing index 94: rincian terlampir
# processing index 95: pt pelayaran bina benua samudera banjarmasin
# processing index 96: cv sabeena rizky perkasa
# processing index 97: pt cirebon energi prasarana cepr
# processing index 98: tidak diketahui namun diduga debitur bni
# processing index 99: bpom di jambi
# processing index 100: panitia proyek sosial pk lpdp
# processing index 101: pegawai pt oigo infrastruktur
# processing index 102: pt pos indonesia kc cirebon
# processing index 103: pt victory chingluh
# processing index 104: cv jangkar pacific
# processing index 105: bank mandiri cabang samarinda
# processing index 106: madrasah muallimaat muhammadiyah yogyakarta
# processing index 107: bri kcp bkkbn
# processing index 108: pemerintah kabupaten penajam paser utara
# processing index 109: panitia lokakarya
# processing index 110: pt pos
# processing index 111: pt skp
# processing index 112: pt kahayan berseri
# processing index 113: kementerian investasi bkpm
# processing index 114: kantor gubernur kalimantan timur
# processing index 115: pengadilan agama sidoarjo
# processing index 116: cls france
# processing index 117: jaya seluler indonesia
# processing index 118: koperasi taxi bali
# processing index 119: pln batubara
# processing index 120: dinas tenaga kerja prov jawa tengah
# processing index 121: pemerintah kabupaten lamandau
# processing index 122: dinas pppa deli serdang
# processing index 123: pt jamkrindo
# processing index 124: pt rizky bumi persada indah
# processing index 125: pt itdc
# processing index 126: pt pegadaian kanwil iv balikpapan
# processing index 127: bank bri cabang blitar
# processing index 128: sasimi
# processing index 129: dapur rindang
# processing index 130: universitas muhammadiyah surakarta
# processing index 131: menteri pertanian
# processing index 132: pt bank bri
# processing index 133: instansi pemerintahan
# processing index 134: notaris hendrik kusalam
# processing index 135: kecamatan gresik
# processing index 136: alazhar islamic university mataram
# processing index 137: pt passokorang
# processing index 138: pt askrindo
# processing index 139: pt
# processing index 140: pengusaha galian tanah urug
# processing index 141: pemerintah provinsi sumsel
# processing index 142: pemerintah kabupaten merangin
# processing index 143: bank bahtermas
# processing index 144: pt kafila pelita sukses
# processing index 145: lpse kabupaten lamongan
# processing index 146: pt absy h hasanuddin
# processing index 147: pt asuransi jasa indonesia cab samarinda
# processing index 148: asn kabid pajak bapenda provinsi lampung
# processing index 149: korporasi
# processing index 150: desa
# processing index 151: direktorat barang kebutuhan pokok dan barang penting
# processing index 152: hendrianto lijaya  ien nio
# processing index 153: koordinator bazis baznas jakarta timur
# processing index 154: pt indonesia comnets plus
# processing index 155: pemerintah kabupaten kutai timur
# processing index 156: instituto para a qualidade de timorleste iqtlip
# processing index 157: pt askrindo kanwil v denpasar
# processing index 158: pemerintah kota cimahi
# processing index 159: bupati sumenep
# processing index 160: cv putra pandawa
# processing index 161: dinas kesehatan provinsi sumatera selatan
# processing index 162: otoritas jasa keuangan
# processing index 163: mdb jombang
# processing index 164: pemerintah kota kediri
# processing index 165: bdk palembang
# processing index 166: pemerintah kabupaten tanah laut
# processing index 167: dpc apsi kota surakarta
# processing index 168: optik beta
# processing index 169: bpk
# processing index 170: kementerian esdm
# processing index 171: pemerintah provinsi sumatera utara
# processing index 172: pt jatiwangi property group
# processing index 173: pelaku usaha di surabaya
# processing index 174: rs pelengkap
# processing index 175: perusahaan batubara
# processing index 176: kepala badan konservasi borobudur
# processing index 177: virama karya
# processing index 178: pnm investment management
# processing index 179: kemenkumham kanwil prov riau
# processing index 180: developer rekanan
# processing index 181: pt bank mandiri cikampek
# processing index 182: kepala staf angkatan laut
# processing index 183: pt pulau rempah indonesia
# processing index 184: rsu mitra sehat
# processing index 185: royal woodpark residences
# processing index 186: pt airmas perkasa
# processing index 187: salah satu perangkat desa
# processing index 188: pemerintah kota singkawang
# processing index 189: kpu kabupaten fakfak
# processing index 190: kedutaan besar china jabatan science counselor
# processing index 191: pt bahana sekuritas
# processing index 192: sd negeri 2 kedung menjangan
# processing index 193: instalasi farmasi klinik erha skin
# processing index 194: bupati halmahera selatan
# processing index 195: kementerian pariwisata dan ekonomi kreatif badan pariwisata dan ekonomi kreatif
# processing index 196: pt pelayaran bunga nusa mahakam  group
# processing index 197: pt bank central asia tbk
# processing index 198: pemerintah kota cilegon
# processing index 199: bank bsi
# processing index 200: inspektorat jenderal tni
# processing index 201: pemerintah kota pontianak
# processing index 202: kapolda kalimantan barat
# processing index 203: dinas pekerjaan umum dan perumahan rakyat pemerintah kota pontianak
# processing index 204: pt bumi daya plaza
# processing index 205: pt sun chang indonesia
# processing index 206: cv indah jaya
# processing index 207: jalan rawa buaya no8 cengkareng jakarta barat
# processing index 208: pemerintah kabupaten wonogiri
# processing index 209: kades penandingan kec pseksu kab lahat
# processing index 210: induk koperasi kepolisian negara inkopol
# processing index 211: kemenkumham
# processing index 212: pt hardaya widya graha
# processing index 213: rsud sidoarjo
# processing index 214: pt pos indonesia
# processing index 215: pt indracipta purisatria
# processing index 216:
# processing index 217: samsul hidayat
# processing index 218: kecamatan pameungpeuk desa
# processing index 219: dinas kesehatan gresik
# processing index 220: pt syabangun bumitirta
# processing index 221: disdik pemkot gorontalo
# processing index 222: komisi pemilihan umum
# processing index 223: pt bnd
# processing index 224: dinas pppa medan
# processing index 225: pt roatex indonesia toll system
# processing index 226: mediatron
# processing index 227: surapita unitrans
# processing index 228: staf
# processing index 229: dinas pemberdayaan masyarakat dan desa kependudukan dan pencatatan sipil provinsi kepulauan riau
# processing index 230: pemerintah kota probolinggo
# processing index 231: kementerian pendidikan kebudayaan riset dan teknologi
# processing index 232: pt jakarta propertindo perseroda
# processing index 233: satuan pendidikan
# processing index 234: pemerintah kabupaten probolinggo
# processing index 235: pt sasa inti jakarta
# processing index 236: rumah bumn wonogiri
# processing index 237: ppbmn kementerian esdm
# processing index 238: dsme
# processing index 239: ex advisor organisasi dan sdm
# processing index 240: pemerintah kabupaten kuningan
# processing index 241: one care solution
# processing index 242: pt tata griya jaya
# processing index 243: ceo asri group
# processing index 244: smk negeri 1 palasah cabang dinas pendidikan wilayah ix provinsi jawa barat
# processing index 245: laboratorium klinik budi sehat
# processing index 246: ksp
# processing index 247: balai besar pengujian perangkat telekomunikasi kementerian kominfo
# processing index 248: politeknik pelayaran surabaya
# processing index 249: pemerintah kabupaten maros
# processing index 250: universitas nusa putra
# processing index 251: cv karuniacipta buana
# processing index 252: cv mitra mandiri
# processing index 253: pt panca konstruksi
# processing index 254: pt hwi
# processing index 255: bssn
# processing index 256: dinas perindustrian dan perdagangan provinsi sumatera barat
# processing index 257: bank mandiri pematang siantar kcp sutomo
# processing index 258: pt bumi alam persada waterboom pesona modern
# processing index 259: pemerintah kabupaten indragiri hilir
# processing index 260: rs mmc
# processing index 261: hotel jw marriot surabaya
# processing index 262: pt smi
# processing index 263: bank rakyat indonesia cabang sintang
# processing index 264: kolektif
# processing index 265: bapenda uppd kota semarang iii
# processing index 266: bpma badan pengelola migas aceh
# processing index 267: mahasiswa s3
# processing index 268: bank sumedang
# processing index 269: kementerian pemberdayaan perempuan dan perlindungan anak
# processing index 270: pemerintah kabupaten gowa
# processing index 271: ptpama kpc
# processing index 272: kepala desa kertonegoro
# processing index 273: desa suban kecamatan tanjung sakti pumu
# processing index 274: politeknik kesehatan karya husuda yogyakarta
# processing index 275: kpknl jakarta v
# processing index 276: perusahaan pengurusan jasa kepabeanan
# processing index 277: arsip nasional republik indonesia
# processing index 278: pt bank pembangunan daerah jawa barat dan banten tbk
# processing index 279: rs semen gresik
# processing index 280: badan koordinasi nasional desa indonesia
# processing index 281: pemerintah bangladesh
# processing index 282: hotel bahtera jaya abadi
# processing index 283: staf exim pt siantar top tbk
# processing index 284: bank indonesia pematangsiantar
# processing index 285: pemerintah kabupaten sumedang
# processing index 286: lembaga administrasi negara
# processing index 287: rina fransisca tjong wajib pajak
# processing index 288: pemda kabupaten tabalong
# processing index 289: bri
# processing index 290: kejaksaan negeri lebak
# processing index 291: pemerintah kabupaten tanah datar
# processing index 292: komisaris  pt blue bird
# processing index 293: bpr serang
# processing index 294: universitas muhammadiyah lamongan
# processing index 295: pt bank negara indonesia persero tbk
# processing index 296: pt ntt emerio
# processing index 297: sesuai data lampiraan
# processing index 298: pt bank rakyat indonesia persero tbk
# processing index 299: ketua forum kades kec mulak ulu kades karang lebak
# processing index 300: bank syariah indonesia bsi kc soekarno hatta malang
# processing index 301: pemerintah kabupaten tegal
# processing index 302: ketua dpp rei
# processing index 303: bank bjb
# processing index 304: pemerintah kabupaten malang
# processing index 305: bank bjb bank bukopin bank btpn bank bsi
# processing index 306: bumd kab karanganyar
# processing index 307: panitia ok oce
# processing index 308: badan penyelenggara jaminan sosial kesehatan
# processing index 309: universitas islam negri uin mataram   panitia the 3rd geotourism festival  international conference
# processing index 310: instansi terlampir
# processing index 311: dinas kelautan perikanan dan peternakan kabupaten cianjur
# processing index 312: kemendikbudristek
# processing index 313: ptpama indominco
# processing index 314: pt kahatex
# processing index 315: notarisppat
# processing index 316: yayasan plan international indonesia
# processing index 317: pt iwip
# processing index 318: rs aisyiah malang rumah sakit
# processing index 319: badan pengelola pendapatan daerah uppd kab purworejo
# processing index 320: pt elo karsa utama
# processing index 321: pt pico tba
# processing index 322: pt indonesia comnets plus icon
# processing index 323: house of trusmi
# processing index 324: pemdes blimbingreko
# processing index 325: aston hotel
# processing index 326: pcc pratama cendekia consultant sebagai penyelenggara workshop
# processing index 327: rs pelengkap medical center
# processing index 328: pt askrindo kc banjarmasin
# processing index 329: pt madu baru pabrik gula  pabrik spiritus madukismo yogyakarta
# processing index 330: rumah sakit fatma
# processing index 331: emc
# processing index 332: pt susi air
# processing index 333: pd bkk temanggung
# processing index 334: pt pindad persero
# processing index 335: direktur utama pt indosat oorodeo hutchison
# processing index 336: group musik
# processing index 337: pt karoseri anak bangsa
# processing index 338: hrd perusahaan pt sumber alfaria trijaya
# processing index 339: kanreg vi bkn medan
# processing index 340: pt perkebunan nusantara holding persero
# processing index 341: pt kayreach system
# processing index 342: pt huawei tech investment huawei indonesia corporate affairs
# processing index 343: ketua pokmas desa putak
# processing index 344: pt kuarta
# processing index 345: kantor notaris hengky budi
# processing index 346: bkpsdm  kabupaten nias barat
# processing index 347: dinas dispora ntb
# processing index 348: pt anggoro karya
# processing index 349: pt usu hydra power
# processing index 350: politeknik pembangunan pertanian malang
# processing index 351: klinik mata jombang
# processing index 352: lab kalibrasi
# processing index 353: vendor penyedia jasa billboard
# processing index 354: pt kredit pintar indonesia
# processing index 355: pd bpr bkk temanggung
# processing index 356: pt bank danamon indonesia tbk
# processing index 357: komisi pemberantasan korupsi
# processing index 358: pemilik
# processing index 359: kantor pos mamuju
# processing index 360: upt bp2mi medan
# processing index 361: iia indonesia
# processing index 362: pemerintah kabupaten bandung barat
# processing index 363: pupuk indonesia
# processing index 364: pemerintah kabupaten ogan komering ilir
# processing index 365: klinik parakita medika
# processing index 366: sekretariat ditjen linjamsos kemensos
# processing index 367: bank bjb cabang cirebon
# processing index 368: pemerintah kabupaten jepara
# processing index 369: badan narkotika nasional palangkaraya
# processing index 370: maximus insurance
# processing index 371: desa songgodadi kec petungkriyono
# processing index 372: asn kepala bidang dikdas kab banggai laut
# processing index 373: sekolah
# processing index 374: bni
# processing index 375: badan pengawas obat dan makanan
# processing index 376: warga
# processing index 377: pt aqua golden mississippi
# processing index 378: bank bri unit prambanan
# processing index 379: pemerintah kabupaten jombang
# processing index 380: pt kordon putra sinergi
# processing index 381: pt organic hans jaya
# processing index 382: pt audie building industry
# processing index 383: pt bank rakyat indonesia
# processing index 384: direktorat sungai danau dan penyeberangan ditjen hub darat kementerian perhubungan
# processing index 385: bpr marunting sejahtera
# processing index 386: kementerian koperasi dan ukm
# processing index 387: ceo panbil nature
# processing index 388: wakil presiden ri
# processing index 389: kantor perwakilan skk migas jawa  bali madura dan nusa tenggara jabanusa
# processing index 390: pemerintah provinsi banten
# processing index 391: pt aster jaya perkasa
# processing index 392: wajib pajak umkm harlen crochet
# processing index 393: pemerintah kabupaten bolaang mongondow timur
# processing index 394: inspektorat kabupaten jayapura
# processing index 395: koperasi karyawan keluarga besar petrokimia gresik k3pg
# processing index 396: pemerintah kabupaten boyolali
# processing index 397: swasta
# processing index 398: pemerintah kabupaten muaro jambi
# processing index 399: kantor skk migas jawa  bali madura dan nusa tenggara
# processing index 400: pt sinar jaya
# processing index 401: pelaku kreatif
# processing index 402: notaris rindiana larasati shmkn
# processing index 403: staf ahli bapak sarmudji dpr ri komisi vi
# processing index 404: pemerintah provinsi sumatera barat
# processing index 405: pt bangun inti sukses indonesia
# processing index 406: cv sinar pelangi indah
# processing index 407: bri cabang temanggung
# processing index 408: indonesia power
# processing index 409: dinas pendidikan dan kebudayaan kota singkawang
# processing index 410: pemerintah kabupaten bombana
# processing index 411: aqua golden mississippi
# processing index 412: pramita laboratorium klinik
# processing index 413: universitas islam indonesia
# processing index 414: pt mutiara bahagia abadi
# processing index 415: tim kabupaten kota kreatif pacitan dan umkm
# processing index 416: pt pln batubara
# processing index 417: pt penjaminan infrastruktur indonesia
# processing index 418: kecamatan pulau pinang
# processing index 419: pt galuh citarum
# processing index 420: pt reasuransi indonesia utama
# processing index 421: pt geo dipa energi persero
# processing index 422: pusat pelaporan dan analisis transaksi keuangan
# processing index 423: pemerintah kota metro
# processing index 424: pt nasmoco magelang
# processing index 425: direktur pengawas umum pt kartika cipta indonesia
# processing index 426: direktorat jenderal pendidikan tinggi riset dan teknologi
# processing index 427: dtcc
# processing index 428: pt mega rosadela propertindo
# processing index 429: koperasi nusantara
# processing index 430: desa sendangsari kecamatan bener
# processing index 431: pt semen gresik persero tbk
# processing index 432: instalatir
# processing index 433: hotel harris
# processing index 434: pemerintah desa bolobungkang
# processing index 435: rs siloam sriwijaya
# processing index 436: pt lawang agung sakti
# processing index 437: pemerintah provinsi nusa tenggara barat
# processing index 438: chairman of tosyali holding
# processing index 439: kemenaker
# processing index 440: bps provinsi sulawesi utara
# processing index 441: unit pengelola kegiatan dana amanah pemberdayaan masyarakat kec gebang
# processing index 442: bethsaida hospital
# processing index 443: pusbang sdm udara
# processing index 444: mitra  perusahaan
# processing index 445: bkd kabupaten mahakam ulu
# processing index 446: md truttys
# processing index 447: pemerintah kota bogor
# processing index 448: badan pengusahaan batam bp batam
# processing index 449: perorangan
# processing index 450: bappeda kota palembang
# processing index 451: pt pembangkitan jawabali pt pjb
# processing index 452: bpjs kesehatan
# processing index 453: pt microsoft indonesia
# processing index 454: pt aneka jasa grhadika
# processing index 455: panin asset management
# processing index 456: pt karunia bersama sejahtera
# processing index 457: polres kapuas hulu
# processing index 458: kementerian perdagangan
# processing index 459: bri kantor pusat
# processing index 460: kementerian sekretariat negara
# processing index 461: subbagian tata laksana bagian oki djkn
# processing index 462: head of partnership siloam group
# processing index 463: kementerian sosial
# processing index 464: pt pal indonesia persero
# processing index 465: pt timah persero tbk
# processing index 466: bumi sindang panon
# processing index 467: kecamatan lebakwangi
# processing index 468: dekranasda provinsi kalimantan barat
# processing index 469: pt kimia farma persero tbk
# processing index 470: bank surya yudha temanggung
# processing index 471: pt bank tabungan negara persero tbk
# processing index 472: pemerintah kota yogyakarta
# processing index 473: mahkamah konstitusi
# processing index 474: ukiran kayu subraman ud bravisga
# processing index 475: pt arthatel
# processing index 476: smkn banjar komite sekolah
# processing index 477: cv berkah solo
# processing index 478: perusahaan swasta
# processing index 479: pt pelita mekar semesta
# processing index 480: pln batubara pln bb
# processing index 481: pemerintah kabupaten
# processing index 482: pt griya persada pangestu
# processing index 483: pt sentral utama teknikal mandiri
# processing index 484: ptt
# processing index 485: perkumpulan
# processing index 486: pengelola global fund tv dinas kesehatan provinsi jawa tengah
# processing index 487: pt elbana abadi jaya
# processing index 488: pengusaha wiraswasta
# processing index 489: bank rakyat indonesia
# processing index 490: pupr
# processing index 491: pengadilan negeri jakarta barat
# processing index 492: pertamina patra niaga
# processing index 493: pt bank pembangunan daerah jawa timur tbk
# processing index 494: pt swadharma sarana informatika
# processing index 495: gp farmasi karanganyar
# processing index 496: pt rizky bumi balangan
# processing index 497: dprd kabupaten malinau
# processing index 498: developer grand pesona
# processing index 499: pt palawi risorsis
# processing index 500: pemerintah kabupaten pamekasan
# processing index 501: bank jago
# processing index 502: cv jaya setya plastik
# processing index 503: tim bahasa global
# processing index 504: pt edco putra jaya
# processing index 505: lurah
# processing index 506: stah dharma sentana sulawesi tengah
# processing index 507: cv mega digital
# processing index 508: pt kereta commuter indonesia
# processing index 509: rs pondok indah
# processing index 510: pemerintah kabupaten sidoarjo
# processing index 511: dinas koperasi dan umkm provinsi sulawesi utara
# processing index 512: pt pertamina
# processing index 513: mantan kades gemidar ilir
# processing index 514: pt asuransi central asia cabang banjarmasin
# processing index 515: badan keuangan dan aset daerah pemkab dairi
# processing index 516: pemerintah kabupaten pesisir selatan
# processing index 517: bni life
# processing index 518: ppk kemayoran
# processing index 519: nestle dan pt beton
# processing index 520: balai keselamatan kerja provinsi jawa tengah
# processing index 521: sdn sambeng 1
# processing index 522: bca cabang palembang
# processing index 523: wakil gubernur sumatera barat
# processing index 524: pemerintah kabupaten karawang
# processing index 525: x digital dokumen
# processing index 526: batan  brin
# processing index 527: kppbc tmp merak
# processing index 528: pemkot mojokerto
# processing index 529: rsat kab ngawi
# processing index 530: advokat
# processing index 531: universitas pancasakti tegal program pascasarjana
# processing index 532: pt gudang garam  pt tri sakti purwosari
# processing index 533: badan penyelenggara jaminan sosial ketenagakerjaan
# processing index 534: dukcapil kota bandung
# processing index 535: wiraswasta
# processing index 536: ibu rumah tangga
# processing index 537: kppbc tmp belawan
# processing index 538: sucor sekuritas
# processing index 539: ombudsman republik indonesia
# processing index 540: bsi cabang parepare
# processing index 541: bank pembangunan daerah bpd lampung
# processing index 542: pt sinar berlian jaya utama andoko abdi
# processing index 543: sekolah dasar negeri 33 talang ubi
# processing index 544: ksp credit union keling kumang
# processing index 545: pt twink indonesia
# processing index 546: pt angkasa pura i persero
# processing index 547: bkd kabupaten probolinggo  bkpsdm kota kediri
# processing index 548: smk nu 1 islamiyah kramat tegal
# processing index 549: sma negeri jumapolo
# processing index 550: pt swa medika
# processing index 551: objek pemeriksaan desa di kecamatan tasikmadu
# processing index 552: pt semen jawa dan pt tambang semen sukabumi
# processing index 553: pemerintah kabupaten hulu sungai selatan
# processing index 554: itp markandeya bali
# processing index 555: pt asuransi ramayana cabang banjarmasin
# processing index 556: pemerintah desa kalangan kecamatan gemolong kabupaten sragen
# processing index 557: pt garuda ukn
# processing index 558: pt jamkrindo kanwil vii banjarmasin
# processing index 559: pemerintah kabupaten serang
# processing index 560: bank mandiri cabang gunungsari
# processing index 561: pemerintah kabupatan malinau
# processing index 562: asosiasi blockchain indonesia
# processing index 563: pegadaian
# processing index 564: pt tkdn
# processing index 565: bri cabang maros
# processing index 566: pt ssi balikpapan
# processing index 567: kantor perwakilan bank indonesia perwakilan kalimantan selatan
# processing index 568: panitia dari badan perencanaan pembangunan penelitian dan pengembangan daerah pemerintah provinsi jawa tengah untuk fgd pemulihan ekonomi akibat dampak covid19 dan perubahan geopolitik di bidang ketahanan energi
# processing index 569: peserta asabri pensiunan polri
# processing index 570: pt taspen
# processing index 571: pt takaya
# processing index 572: pegawai bank
# processing index 573: bpd jateng capem ngadirejo
# processing index 574: pt hariff
# processing index 575: pt perusahaan gas negara persero tbk
# processing index 576: btn
# processing index 577: dprd cianjur
# processing index 578: pt hutama karya persero
# processing index 579: ok oce
# processing index 580: upk pnpm mpd kec loano
# processing index 581: kpj medica
# processing index 582: buruh harian
# processing index 583: pt garuda indonesia persero tbk
# processing index 584: pt golden compas indonesia
# processing index 585: bkd kabupaten nias barat
# processing index 586: kepala man 2 mojokerto
# processing index 587: walikota blitar
# processing index 588: pt sapta sarana sejahtera
# processing index 589: kadis pppa kabupaten gorontalo utara
# processing index 590: pemerintah kabupaten tanggamus
# processing index 591: balai penyuluhan pertanian kecamatan pakuniran
# processing index 592: pemerintah kabupaten malinau
# processing index 593: pemerintah desa kedawong diwek
# processing index 594: pemerintah kota mojokerto
# processing index 595: pt kebon agung
# processing index 596: yayasan nur saadah dimyati
# processing index 597: duta besar qatar
# processing index 598: smk 1 pinrang
# processing index 599: bappeda kabupaten tanggamus
# processing index 600: anggota dpr ri
# processing index 601: asuransi sinarmas
# processing index 602: badan pengawasan
# processing index 603: danlanal lhokseumawe
# processing index 604: kajari maros
# processing index 605: pemerintah kabupaten musi rawas
# processing index 606: pt hexing technology
# processing index 607: cv nuansa kreasindo
# processing index 608: dewan perwakilan rakyat
# processing index 609: pt bank tabungan negara
# processing index 610: pt taman wisata candi borobudur prambanan dan ratu boko persero
# processing index 611: bahalap hotel palangkaraya
# processing index 612: pegawai bbpom di padang
# processing index 613: dispar kabupaten manggarai barat
# processing index 614: pt jakarta industrial estate pulogadung
# processing index 615: universitas slamet riyadi surakarta
# processing index 616: pegawai bank negara indonesia
# processing index 617: pemerintahan kota
# processing index 618: pt pesona purnama
# processing index 619: pt surveyor indonesia
# processing index 620: rustini hartati sh mkn dan staf
# processing index 621: pt impala akbarindo  penyedia jasa outsourcing cleaning services
# processing index 622: pt cipta karya millenia kalsel
# processing index 623: dinas penanaman modal dan pelayanan terpadu satu pintu kabupaten pelalawan
# processing index 624: lembaga penyelenggara pelatihan dan seminar
# processing index 625: sila butik batik
# processing index 626: pt global mandiri ekapratama
# processing index 627: dinas koperasi dan ukm kabupaten subang
# processing index 628: pemerintah kabupaten sumba tengah
# processing index 629: itb
# processing index 630: tribun kaltim
# processing index 631: dpd himperra kalimantan selatan
# processing index 632: pt jamkrindo cabang samarinda
# processing index 633: penyedia jasa instalatir listrik
# processing index 634: postobello
# processing index 635: bni divisi solusi ritel
# processing index 636: pt angkasa pura ii persero
# processing index 637: hotel santika ambon
# processing index 638: wajib pajak
# processing index 639: uptd puskesmas padurenan
# processing index 640: pihak swasta
# processing index 641: jamsostek
# processing index 642: pt medika maesindo global
# processing index 643: pt arkiatama dan arbasel
# processing index 644: kantor skk migas jawa  bali madura dan nusa tenggara jabanusa
# processing index 645: pt busana remaja agracipta
# processing index 646: perumda
# processing index 647: rs ciputra banjarmasin
# processing index 648: dinas perpustakaan
# processing index 649: bri custody
# processing index 650: perumahan villa kota intan
# processing index 651: oy indonesia
# processing index 652: ikatan kosultan pajak indonesia ikpi cabang jakarta barat
# processing index 653: pt cjwi temanggung
# processing index 654: pemerintah kabupaten sumenep
# processing index 655: kepala seksi intelejen kejaksaan negeri kota kediri
# processing index 656: pemerintah provinsi jawa tengah
# processing index 657: pemerintah kabupaten bojonegoro
# processing index 658: notaris
# processing index 659: pemerintah kabupaten luwu utara
# processing index 660: kecamatan pulomerak
# processing index 661: disnaker kab serang
# processing index 662: pt rekamitra cipta tambang
# processing index 663: lima jaya lestari
# processing index 664: penerbit gramedia
# processing index 665: rsud jombang
# processing index 666: pt zurich topas life
# processing index 667: pejabat lelang kelas ii
# processing index 668: sekda kabupaten garut  pns
# processing index 669: badan penyelesaian sengketa konsumen gorontalo
# processing index 670: bloomberg
# processing index 671: waki konsultan jenderal cina
# processing index 672: dinas pemberdayaan masayrakat dan desa kabupaten semarang
# processing index 673: pt finnet indonesia
# processing index 674: koperasi
# processing index 675: pt adhi karya
# processing index 676: kodim sidoarjo
# processing index 677: toko central cctv
# processing index 678: bosowa asuransi
# processing index 679: bagian organisasi setda kabupaten banggai laut
# processing index 680: kepolisian daerah provinsi di yogyakarta
# processing index 681: bankaltimtara
# processing index 682: pt keska lestari
# processing index 683: the indonesian iron  steel industry association iisia
# processing index 684: mantan pj kepala desa kalidandan
# processing index 685: penulis dan konsultan
# processing index 686: pemerintah kabupaten siak
# processing index 687: laboratorium kalibrasi pt indofood
# processing index 688: puskesmas kedu
# processing index 689: kodim 0609 cimahi
# processing index 690: pemdes kejuden
# processing index 691: badan amil zakat nasonal provinsi jawa timur
# processing index 692: pt langkat laut timur
# processing index 693: bkad kecamatan susukan
# processing index 694: pemerintah kabupaten lamongan
# processing index 695: bank bri cab fakfak
# processing index 696: pemerintah kota tebing tinggi
# processing index 697: pt msinfokom
# processing index 698: dinas kesehatan kabupaten gresik
# processing index 699: pt tri dharma proteksi
# processing index 700: peserta
# processing index 701: pratindo canggih mulia
# processing index 702: pt persona prima utama ppu
# processing index 703: perum bulog kanwil kaltim  kaltara
# processing index 704: pt sri rejeki fertilizer
# processing index 705: adkasi asosiasi dprd kabupaten seluruh indonesia
# processing index 706: sekolah kecamatan kebun tebu lampung barat
# processing index 707: exxonmobil
# processing index 708: eksportir ikan wajib pajak
# processing index 709: komisi
# processing index 710: mahasiswa unjani
# processing index 711: universitas airlangga
# processing index 712: mentari intercultural school bintaro
# processing index 713: aji suryana jj sh
# processing index 714: cv layar era
# processing index 715: mantan direktur lembaga pengembangan perbankan indonesia lppi
# processing index 716: pt huawei tech investment public relation manager
# processing index 717: rahasia
# processing index 718: bank woori saudara
# processing index 719: pt caterindo citra rasa
# processing index 720: dewan perwakilan rakyat daerah
# processing index 721: fujitsu indonesia
# processing index 722: ketua forum kades kec suka merindu
# processing index 723: unit penyelenggara bandar udara ilaga
# processing index 724: pt pegadaian area samarinda
# processing index 725: pt transportasi gas indonesia transgasindo
# processing index 726: pt pgn
# processing index 727: kepala seksi intelijen kejaksaan negeri kota kediri
# processing index 728: kades lubuk seketi kec kikim barat
# processing index 729: dinas kesehatan asahan
# processing index 730: warung makan ayam geprek keprabon
# processing index 731: desa pasir reungit
# processing index 732: notaris ppat kabupaten hulu sungai tengai
# processing index 733: pemerintah kabupaten bolaang mongondow
# processing index 734: deputi bidang investasi kementerian pariwisata dan ekonomi kreatif
# processing index 735: kepala badan pengelolaan pendapatan daerah provinsi nusa tenggara barat
# processing index 736: pt samuel sekuritas indonesia
# processing index 737: cv anugerah semesta bangka otakotak ase
# processing index 738: askrindo insurance
# processing index 739: kemenkopukm
# processing index 740: pengelola apartemen aspen
# processing index 741: pt erze bumi harmoni
# processing index 742: pt dana tabungan dan asuransi pegawai negeri   taspen persero
# processing index 743: pt annisa rizqi pratama
# processing index 744: anggota komisi v dpr ri
# processing index 745: kedubes prc
# processing index 746: bank bri
# processing index 747: pt mustika eka unggul
# processing index 748: djbc
# processing index 749: pt asdp indonesia ferry persero
# processing index 750: pt inalum
# processing index 751: pemerintah kota batam
# processing index 752: pelaku usaha umkm pangan
# processing index 753: h sudarmadi sh mkn
# processing index 754: pegawai pppk kemenkeu
# processing index 755: cv owen mart
# processing index 756: badan pendapatan daerah provinsi kalimantan timur
# processing index 757: pemerintahan kota tangerang
# processing index 758: bapenda kabupaten bandung barat
# processing index 759: kementerian koperasi dan ukm ri
# processing index 760: pemerintah kabupaten subang
# processing index 761: kpp pratama medan barat
# processing index 762: pt fresh galang mandiri consultant
# processing index 763: balai latihan kerja padang
# processing index 764: rektor universitas madura
# processing index 765: dispar halmahera barat
# processing index 766: pt bio farma persero
# processing index 767: dharma wanita persatuan kemendagri
# processing index 768: pt buran nusa respati  group
# processing index 769: pt bank bni kantor cabang karawang
# processing index 770: cv berkah eina
# processing index 771: pemerintah kabupaten demak
# processing index 772: smp satu atap negeri talun
# processing index 773: rsud prof dr margono soekarjo
# processing index 774: bumn
# processing index 775: owner ninoas edutainment
# processing index 776: pt setia thenoch
# processing index 777: pt deltomed wonogiri
# processing index 778: formula e
# processing index 779: djkn kemenkeu
# processing index 780: pemerintah kota cirebon
# processing index 781: dinas komunikasi dan informatika provinsi papua
# processing index 782: taraskop koperasi pegawai
# processing index 783: rsui madinah kesembon
# processing index 784: cv inti citra usaha
# processing index 785: pemerintah kabupaten sintang
# processing index 786: pemerintah kabupaten gresik
# processing index 787: pemerintah daerah tingkat ii
# processing index 788: smkn 4 sukabumi
# processing index 789: pt keong nusantara abadi
# processing index 790: pelita travel
# processing index 791: pt nusantara jaya raya mujur
# processing index 792: pemerintah desa wonorejo kec jatiyoso
# processing index 793: kpn baji artha
# processing index 794: apindo
# processing index 795: bank bukopin bri dan bsi
# processing index 796: kecamatan lahat selatan
# processing index 797: bank nasional indonesia bni 46 cabang pangkalan bun
# processing index 798: smk negeri jatipuro
# processing index 799: pramesty catering
# processing index 800: kpp pratama jakarta kebayoran baru dua
# processing index 801: distributor granit niro
# processing index 802: pemerintah kota bekasi
# processing index 803: pt askrindo kc tarakan
# processing index 804: komisi vi dpr ri
# processing index 805: kanwil kemenag provsumatera selatan
# processing index 806: jpe
# processing index 807: pt wijaya mandiri tintex
# processing index 808: pt panca perkasa indoprima
# processing index 809: dewan kerajinan nasional daerah kabupaten kapuas hulu
# processing index 810: pt dunia media dinamika informasi
# processing index 811: pt distriversa buana mas semarang
# processing index 812: lucy indriani sh mkn
# processing index 813: pemerintah provinsi kalimantan barat
# processing index 814: pt cinere serpong jaya
# processing index 815: pt daikin
# processing index 816: pt angkasa pura i
# processing index 817: pt aneka nusantara internasional
# processing index 818: pt bank dki jakarta
# processing index 819: pt eria makmur
# processing index 820: alibabacloud
# processing index 821: pemerintah kota serang
# processing index 822: pelaku umkm
# processing index 823: partai demokrat
# processing index 824: kemenko marves
# processing index 825: pt pln
# processing index 826: desa jatisuko
# processing index 827: pt wanasalam samudra maju makmur
# processing index 828: kecamatan sukodono
# processing index 829: pemilik dqta aja resto
# processing index 830: inspektorat kabupaten sumenep
# processing index 831: pemerintah kabupaten empat lawang
# processing index 832: pt bank centra asia tbk corporate banking group
# processing index 833: bangladesh
# processing index 834: pemerintah kota banjar
# processing index 835: setda kabupaten bengkalis
# processing index 836: wakil bupati sumba tengah
# processing index 837: rspal dr ramelan
# processing index 838: pt jasa marga
# processing index 839: pt oxy gemilang jaya
# processing index 840: pt prasasti nusa lestari
# processing index 841: dpd apersi kalsel
# processing index 842: bank bni cabang maros
# processing index 843: kppbc tipe madya pabean a bekasi
# processing index 844: pt jamkrindo kanwil viii banjarmasin  kc tarakan
# processing index 845: pt timah tbk
# processing index 846: pt surya bersama propertindo
# processing index 847: pt bangun askrida syariah
# processing index 848: deputi bidang industri dan investasi kementerian pariwisata dan ekonomi kreatif
# processing index 849: pt pertamina lubricants
# processing index 850: pt dagu komunika
# processing index 851: suhartini
# processing index 852: pt telkom pcc
# processing index 853: pt binayasa putra batara
# processing index 854: bprs harta insan karimah bahari
# processing index 855: perum kehutanan negara perhutani
# processing index 856: lembaga layanan pendidikan tinggi wilayah vi jawa tengah
# processing index 857: pt cahaya samtraco utama
# processing index 858: pengusaha wajib pajak
# processing index 859: pemerintah kota gorontalo
# processing index 860: inspektorat jenderal kementerian pertanian
# processing index 861: mahasiswa universitas diponegoro semarang
# processing index 862: pt hema medhajaya
# processing index 863: pt kertas padalarang
# processing index 864: pt asuransi tri pakarta
# processing index 865: badan usaha jalan tol pt cibitung tanjung priok port tollways
# processing index 866: pt bunaken jaya
# processing index 867: istri wakil bupati jember
# processing index 868: jatrista digital printing
# processing index 869: pemerintah kabupaten sragen
# processing index 870: pt telkom
# processing index 871: standard chartered indonesia
# processing index 872: direktur operasional pt taspen
# processing index 873: stah lampung
# processing index 874: peruri
# processing index 875: ikanas stan charity golf
# processing index 876: mandarin oriental jakarta
# processing index 877: layanan rental mobil
# processing index 878: pemerintah provinsi kalimantan utara
# processing index 879: pt graha karya raya bersama
# processing index 880: pihak pasar nanggelan bali yang dinilai
# processing index 881: pt milenium kreasi
# processing index 882: kepala desa karangkamulyan kecamatan cijeungjing kabupaten ciamis
# processing index 883: gubernur maluku
# processing index 884: dinas pupr
# processing index 885: smec group
# processing index 886: bsi kc bima soetta 1
# processing index 887: pegawai kemendikbudristek
# processing index 888: pln uiw ntb dan pln uip nusra
# processing index 889: data terlampir
# processing index 890: pt saddam jaya perkasa
# processing index 891: bni kantor wilayah 12
# processing index 892: unit uppd samsat 2 kayutangi
# processing index 893: kim pamekasan hebat
# processing index 894: konsultan pajak
# processing index 895: cv hasil laut nusantara
# processing index 896: kab magetan
# processing index 897: pt dongjin
# processing index 898: pt pelindo
# processing index 899: pemerintah kabupaten sleman
# processing index 900: kepala bbpom di pekanbaru
# processing index 901: bank mandiri cabang maros
# processing index 902: bank bca
# processing index 903: bio farma
# processing index 904: pt mayasari bakti
# processing index 905: malaysia eximbank
# processing index 906: kepala bbpom pekanbaru
# processing index 907: desa patobong
# processing index 908: pt kelola agro makmur
# processing index 909: tidak diketahui
# processing index 910: pt mnc pictures
# processing index 911: rspp
# processing index 912: pt naga mas mulia
# processing index 913: pt cj feed and care indonesia
# processing index 914: perum lembaga penyelenggara pelayanan navigasi penerbangan indonesia airnav
# processing index 915: pt global selaras medika
# processing index 916: dinas kesehatan kabupaten kampar
# processing index 917: ukm
# processing index 918: kades pelajaran ketua forum kec jarai
# processing index 919: bri kacap banjarnegara
# processing index 920: dinas kesehatan provinsi kalimantan selatan
# processing index 921: pns staf di kelurahan pemaluan
# processing index 922: unit penyelenggara pelabuhan kelas iii mesuji
# processing index 923: rs bangli midika canti
# processing index 924: rsup dr sardjito
# processing index 925: pt bank dbs indonesia
# processing index 926: direktorat jenderal tanaman pangan
# processing index 927: sarasa
# processing index 928: esri indonesia
# processing index 929: pt akar bumi
# processing index 930: badan meteorologi klimatologi dan geofisika
# processing index 931: bank rakyat indonesia samarinda 1
# processing index 932: data science indonesia
# processing index 933: developer
# processing index 934: sma pulokulon kabupaten grobogan
# processing index 935: pt asuransi tri pakarta cabang banjarmasin
# processing index 936: pt monex investindo futures
# processing index 937: djp
# processing index 938: umkm sleman
# processing index 939: lembaga penjamin simpanan
# processing index 940: pemerintah kabupaten cirebon
# processing index 941: sekretariat perwakilan kementerian keuangan sulawesi barat
# processing index 942: fovere hotel palangkaraya
# processing index 943: pt naku freight indonesia
# processing index 944: toko alat tulis hikmah
# processing index 945: pemerintah kota
# processing index 946: perseorangan
# processing index 947: tamu pernikahan
# processing index 948: perum perumnas proyek lampung
# processing index 949: mandiri club prudential life assurance visionet internasional pefindo biro kredit
# processing index 950: kepala desa dondo soboli
# processing index 951: bapenda wilayah kabupaten bandung barat
# processing index 952: pt mnc guna usaha indonesia
# processing index 953: triklin rekatama
# processing index 954: universita pertamina
# processing index 955: pt maulidya mandiri propertindo
# processing index 956: dosen pasca sarjana fakultas hukum ui menteri agraria dan tata ruang indonesia ke13
# processing index 957: refinitiv services indonesia
# processing index 958: yayasan islam thursina malang
# processing index 959: bpjs ketenagakerjaan cabang sidoarjo
# processing index 960: revinitif
# processing index 961: kementerian kelautan dan perikanan
# processing index 962: jasindo
# processing index 963: uptd pasar lematang kabupaten lahat
# processing index 964: embassy of bangladesh
# processing index 965: ruddyantho tantry sh
# processing index 966: pbf pt united dico citas
# processing index 967: pt mars internasional indonesia mii
# processing index 968: dokter
# processing index 969: kanwil djbc papua kanwil sulbagsel djbc sorong
# processing index 970: hallo mart singkawang
# processing index 971: apotik kimia farma ub jember
# processing index 972: gerindra
# processing index 973: universitas prasetiya mulya
# processing index 974: bumdes delta mulia kabupaten pamekasan
# processing index 975: dr solecha skin care
# processing index 976: pawon catering
# processing index 977: pelaksana bppk kemenkeu ri  pns
# processing index 978: jakarta international container terminal jict
# processing index 979: universitas ngurah rai bali
# processing index 980: balai teknik perkeretaapian wilayah jakarta dan banten
# processing index 981: pt jasamarga semarang batang
# processing index 982: bank bpd jateng
# processing index 983: pt defas lineko bersama
# processing index 984: pt nusantara infrastruktur
# processing index 985: pemerintah desa kejuden
# processing index 986: pensiunan
# processing index 987: pemerintah daerah mojokerto
# processing index 988: pemerintah kabupaten paser
# processing index 989: operator desa kalidandan dan desa blimbing
# processing index 990: wakil gubernur jawa timur
# processing index 991: pemerintah kota tasikmalaya
# processing index 992: pt karya mitra budi sentosa
# processing index 993: pemerintah kota banjarbaru
# processing index 994: pt bungasari flour mills indonesia
# processing index 995: rekanan vendor
# processing index 996: industri makanan
# processing index 997: the trans luxury hotel
# ...
# processing index 1832: perusahaan asuransi
# processing index 1833: pt pegadaian
# processing index 1834: pt quantum analytics teknikatama
# processing index 1835: pt bahana cipta internusa
# processing index 1836: pt kawasan industri makassar kima persero
# processing index 1837: kelompok petani bawang samili
# processing index 1838: pemkot jambi
# processing index 1839: lab prodia klaten
# processing index 1840: dinas pp kab pesisir selatan
# processing index 1841: pt tampan family corp
# processing index 1842: tamu undangan pernikahan
# processing index 1843: direktorat rehsos lanjut usia
# processing index 1844: universitas tarumanegara
# processing index 1845: bea dan cukai kementerian keuangan
# processing index 1846: pt petrokopindo cipta selaras
# processing index 1847: gramedia
# processing index 1848: pt rajawali nusindo
# processing index 1849: kejaksaan tinggi provinsi jawa tengah
# processing index 1850: desa pematang jaya
# processing index 1851: pt swamedika
# processing index 1852: pt graha sativa indonesia
# processing index 1853: tamu undangan
# processing index 1854: cv mandiri sejahtera
# processing index 1855: klinik mata rs nu jombang dan rs pelengkap
# processing index 1856: pt omron manufacturing of indonesia bekasi
# processing index 1857: biro perekonomian provinsi jawa barat
# processing index 1858: pelaku ekraf desa pasir panjang
# processing index 1859: gramedia gajah mada
# processing index 1860: candigolf
# processing index 1861: pemerintah kabupaten sampang
# processing index 1862: pt ame
# processing index 1863: hasta mitra baruna
# processing index 1864: dpd rei kalimantan selatan
# processing index 1865: pt softwareone indonesia
# processing index 1866: kedubes rrt
# processing index 1867: kecamatan bareng kabupaten jombang
# processing index 1868: tamu undangan terlampir
# processing index 1869: sales pt mahkota nusantara
# processing index 1870: kepala bppw jambi ditjen cipta karya kementerian pupr
# processing index 1871: pemerintah kabupaten banyumas
# processing index 1872: pt sarana multi infrastruktur persero pt smi
# processing index 1873: dpppa ogan komering ilir
# processing index 1874: walikota
# processing index 1875: pt cheong song
# processing index 1876: informa
# processing index 1877: ekspedisi sinar aji cepat bhayangkara
# processing index 1878: dinas pengendalian penduduk dan keluarga berencana kab muna barat
# processing index 1879: pt hanim setia cemerlang
# processing index 1880: pt formulatrix
# processing index 1881: direktorat jenderal pajak
# processing index 1882: danyon tni
# processing index 1883: toko mutiara herbal
# processing index 1884: bank jabar sumedang
# processing index 1885: dprd kota tegal
# processing index 1886: pt intermedia
# processing index 1887: building management nifarro
# processing index 1888: kementerian ketenagakerjaan
# processing index 1889: pemerintah provinsi jawa barat
# processing index 1890: pemerintah kabupaten rembang
# processing index 1891: pemerintah provinsi dki jakarta
# processing index 1892: laboratorium prodia
# processing index 1893: umot herbal sinar bambu kuning
# processing index 1894: kecamatan ngraho
# processing index 1895: pt tanjungraya intiwira
# processing index 1896: pemerintah kabupaten bangkalan
# processing index 1897: tidak tau
# processing index 1898: direktur pt bukit asam tbk
# processing index 1899: dinas pendidikan kabupaten serdang bedagai
# processing index 1900: pt bhumi phala perkasa
# processing index 1901: ganesha operation
# processing index 1902: pt bri cabang bojonegoro dan pt bri cabang nganjuk
# processing index 1903: pt taspen pt bank mandiri banggar dpr pt bank syariah indonesia
# processing index 1904: badan
# processing index 1905: pt aneka tambang persero tbk
# processing index 1906: bpkp
# processing index 1907: pt dinamika sejahtera mandiri
# processing index 1908: pns
# processing index 1909: polda
# processing index 1910: inspektorat kabupaten pringsewu
# processing index 1911: kuasa wajib pajak atas nama pt tri daya kreasi
# processing index 1912: asn kepala smpn 1 biau
# processing index 1913: bendahara desa
# processing index 1914: rumah sakit swasta di solo
# processing index 1915: pt computa
# processing index 1916: isei ikatan sarjana ekonomi indonesia caban jakarta
# processing index 1917: pp perbasi
# processing index 1918: pt bank pembangunan daerah kalimantan selatan
# processing index 1919: cv dini jaya
# processing index 1920: universitas bondowoso
# processing index 1921: pt muhibah abadi
# processing index 1922: pt anugerah lautan perkasa  pt anugerah djam sawit
# processing index 1923: yayasan putra putri cemeralng
# processing index 1924: bank woori saudara cabang surapati core
# processing index 1925: pt bpr kerta raharja gemilang
# processing index 1926: pt mrt jakarta
# processing index 1927: pt tanjung krida perkasa
# processing index 1928: debitur
# processing index 1929: mitra pengandaan barang
# processing index 1930: pakis hasanah smart living
# processing index 1931: desa karangkamulyan
# processing index 1932: catering resto semeru batam
# processing index 1933: nasabah pemilik toko
# processing index 1934: pt sembilan bintang
# processing index 1935: hotel griya persada  bandungan
# processing index 1936: bkkbn provinsi sulawesi utara
# processing index 1937: bpsdm lampung
# processing index 1938: tim catering
# processing index 1939: kepolisian
# processing index 1940: balai besar pom di surabaya
# processing index 1941: pt nusantara compnet integrator
# processing index 1942: pt griya mapan alami
# processing index 1943: huawei innovation center indonesia
# processing index 1944: pemerintah kabupaten deli serdang
# processing index 1945: kantor wilayah badan pertanahan nasional provinsi jawa tengah
# processing index 1946: bank bri pematang siantar
# processing index 1947: japfa
# processing index 1948: tax function department staff pt bga
# processing index 1949: badan pengawasan keuangan dan pembangunan bpkp
# processing index 1950: kades guru agung kec suka merindu
# processing index 1951: smk rpi jakarta
# processing index 1952: mitra kerja
# processing index 1953: biro logistik polda jawa tengah
# processing index 1954: persatuan ahli farmasi indonesia
# processing index 1955: pjs kepala desa kepala siring kec kikim timur
# processing index 1956: pengurus pusat perkumpulan filatelis indonesia
# processing index 1957: kantor perwakilan skk migas jawa  bali madura dan nusa tenggara
# processing index 1958: cv lebok 023734849805000
# processing index 1959: luwes pati
# processing index 1960: staff operasional pt berkah berjaya energi indonesia
# processing index 1961: dinas kearsipan dan perpustakaan kabupaten pelalawan
# processing index 1962: pt hasil melimpah
# processing index 1963: komisaris pt cassadna rudi atip
# processing index 1964: sarana jaya properindo
# processing index 1965: pemerintah kota balikpapan
# processing index 1966: bkpsdm
# processing index 1967: kecamatan rubaru
# processing index 1968: industri karak bolon daerah colomadu
# processing index 1969: notaris peni inggriani sm
# processing index 1970: pt bio farma bandung
# processing index 1971: pemerintah kabupaten pringsewu
# processing index 1972: kantor notaris
# processing index 1973: pt ligno
# processing index 1974: ptkrakatau tirta industri
# processing index 1975: walikota pagar alam
# processing index 1976: inspektorat daerah
# processing index 1977: pt asuransi jasindo
# processing index 1978: perusahaan sawit
# processing index 1979: camat muara payang an forum kades muara payang
# processing index 1980: anggota dprd provinsi jawa barat
# processing index 1981: sekretariat inspektorat
# processing index 1982: wali murid
# processing index 1983: mandiri investama sejati
# processing index 1984: pt marga sarana jabar
# processing index 1985: pt js corp
# processing index 1986: ketua gekraf dan umkm
# processing index 1987: pt bank pembangunan daerah sumatera utara
# processing index 1988: apotek varia
# processing index 1989: mantan wakil presiden ri
# processing index 1990: holland bakery
# processing index 1991: muamlat institute
# processing index 1992: poongsan
# processing index 1993: mantan penanggungjawab kepala desa ranon
# processing index 1994: kemenpora
# processing index 1995: pemerintah kabupaten belitung
# processing index 1996: huawei
# processing index 1997: desa lakawali pantai kecamatan malili kabupaten luwu timur
# processing index 1998: reskrim kalteng
# processing index 1999: purchasing officer vendor
# processing index 2000: pemerintah kabupaten magelang
# processing index 2001: tim fsm film sunday movie
# processing index 2002: pt pegadaian probolinggo
# processing index 2003: pt usda seroja jaya
# processing index 2004: pt qualis indonesia
# processing index 2005: tni angkatan udara
# processing index 2006: pemerintah desa karangkamulyan
# processing index 2007: dpp perbarindo
# processing index 2008: erha fashion
# processing index 2009: pkk grobogan
# processing index 2010: kpp pratama lhokseumawe
# processing index 2011: dispermasdes kabupaten semarang
# processing index 2012: direktur tanjung harapan sentra nusa
# processing index 2013: kementerian lingkungan hidup dan kehutanan
# processing index 2014: pt anargya aset management
# processing index 2015: awadee lpdp
# processing index 2016: pt zte indonesia
# processing index 2017: grup mining industri indonesia mind id
# processing index 2018: bkpsdm kabupaten tanggamus
# processing index 2019: pelaku usaha umkm teh senduru
# processing index 2020: pt pegadaian persero
# processing index 2021: kedutaan besar australia
# processing index 2022: bumd pdam kota salatiga
# processing index 2023: universitas hindu negeri i gusti bagus sugriwa denpasar
# processing index 2024: bank bpd diy
# processing index 2025: pt combina costraco
# processing index 2026: warga di desa malasari kecamatan cimaung kab bandung
# processing index 2027: rs bina sehat
# processing index 2028: pjs kepala desa penantian kecamatan pagar gunung
# processing index 2029: pt thorcon power indonesia
# processing index 2030: pt bank mandiri persero tbk
# processing index 2031: pt berkah serayu dinata
# processing index 2032: pt jamkrindo kanwil viii banjarmasin
# processing index 2033: pt berkah integra gemilang sejati
# processing index 2034: uppd kabupaten demak
# processing index 2035: kantor pertanahan kabupaten temanggung
# processing index 2036: universitas muhamadiyah jakarta
# processing index 2037: bappeda litbang kota palembang
# processing index 2038: pt haji muhammad taher dan pt sinar jaya bersaudara
# processing index 2039: busana apparel
# processing index 2040: cv aspira utama
# processing index 2041: pt chikal prima rasa
# processing index 2042: pt indocev
# processing index 2043: pt saba transindo
# processing index 2044: dinas komunikasi informatika dan statistik kabupaten bandung
# processing index 2045: tim kurator pt langgam inti hibrindo dalam pailit
# processing index 2046: vendor namun tidak mengetahui namanya
# processing index 2047: bank neo commerce
# processing index 2048: balai pom bengkulu
# processing index 2049: bank sumsel babel
# processing index 2050: tidak diketrahui
# processing index 2051: gereja kristen indonesia
# processing index 2052: pemerintah provinsi jawa timur
# processing index 2053: unpad
# processing index 2054: pura group kudus
# processing index 2055: pt anomali lumbung artha
# processing index 2056: notaris muhammad rusdy
# processing index 2057: pegawai kpp badora
# processing index 2058: pemerintah kabupaten sinjai
# processing index 2059: pt teknonologi merlin sejahtera uku
# processing index 2060: pt cort
# processing index 2061: panitera pn jakarta selatan
# processing index 2062: atase polisi filifina
# processing index 2063: sekretaris dewan pengawas bpjstk
# processing index 2064: cv global angkasa nusa
# processing index 2065: perum jasa tirta i
# processing index 2066: pt prosehat
# processing index 2067: tni  polri
# processing index 2068: indonesia shipping agencies associated isaa
# processing index 2069: tidak di ketahui
# processing index 2070: pt permodalan nasional madani persero
# processing index 2071: bpkad kab lingga
# processing index 2072: infocomm media development authority singapore
# processing index 2073: dir pengawas dan operasional pt kci
# processing index 2074: duta putra land
# processing index 2075: universitas terbuka banjarmasin
# processing index 2076: pt bank lampung
# processing index 2077: kantor regional xiv bkn manokwari
# processing index 2078: pt birama binakom
# processing index 2079: pt mandiri sukses lancar jaya gemilang
# processing index 2080: wk ketua forum kades kec kikim timur kades purwarejo
# processing index 2081: kementrian pupr
# processing index 2082: bank bpd bali cabang gianyar
# processing index 2083: bpsdm sulsel
# processing index 2084: erha clinic
# processing index 2085: pt unicer indoasia
# processing index 2086: pt sanofi
# processing index 2087: pt bapamco inti pradana
# processing index 2088: dinas perhubungan kota semarang
# processing index 2089: pemerintah bangka selatan
# processing index 2090: polres batang
# processing index 2091: camat negeri agung
# processing index 2092: sma swasta
# processing index 2093: kementerian
# processing index 2094: laboratorium fortuna mojokerto
# processing index 2095: pemerintah kabupaten pangkajene dan kepulauan
# processing index 2096: jamsyar balikpapan
# processing index 2097: pemerintah kabupaten pati
# processing index 2098: pt bakrie  brother tbk
# processing index 2099: kantor desa
# processing index 2100: dkpp
# processing index 2101: pt sinergi transmedia
# processing index 2102: kantor notaris liana maria
# processing index 2103: eks pekerja
# processing index 2104: pt rapp
# processing index 2105: bri dan btn
# processing index 2106: pemprov lampung
# processing index 2107: badan pusat statistik
# processing index 2108: ypia
# processing index 2109: kementerian pendayagunaan aparatur negara dan reformasi birokrasi
# processing index 2110: pt perusahaan listrik negara persero
# processing index 2111: staf  dinas cipta karya provinsi sulawesi tenggara
# processing index 2112: pt dbs vickers sekuritas indonesia
# processing index 2113: dpmd kabupaten garut
# processing index 2114: bank mandiri kcp jakarta departemen keuangan
# processing index 2115: badan musyawarah perbankan daerah bmpd kalimantan barat
# processing index 2116: freelance
# processing index 2117: vendor
# processing index 2118: tidak mengetahui
# processing index 2119: mahasiswa
# processing index 2120: bpd sulteng cabang luwuk
# processing index 2121: dua creative production
# processing index 2122: desa kembang kuning
# processing index 2123: pt foirmulatrx salatiga
# processing index 2124: universitas aisyiyah yogyakarta
# processing index 2125: kementerian luar negeri
# processing index 2126: satuan kerja khusus pelaksana kegiatan usaha hulu minyak dan gas bumi
# processing index 2127: pt kmi
# processing index 2128: ace hardware
# processing index 2129: pt asuransi aswata
# processing index 2130: pt artha boga
# processing index 2131: pltu
# processing index 2132: bpsdm kemen esdm
# processing index 2133: politeknik kesehatan karya husada yogyakarta
# processing index 2134: kemenkumham kanwil jambi
# processing index 2135: kepala desa cikareo selatan kabupaten sumedang
# processing index 2136: pengadilan tinggi agama semarang
# processing index 2137: lilian amarilia ramadhani sh mkn
# processing index 2138: pemerintah kota pekalongan
# processing index 2139: purna pekerja migran indonesia
# processing index 2140: badan kependudukan dan keluarga berencana nasional
# processing index 2141: pemerintah provinsi bali
# processing index 2142: pt yobel utama seafood indonesia
# processing index 2143: bank bri kantor cabang bkkbn
# processing index 2144: cv haliza
# processing index 2145: hernawan wangdana sh mkn
# processing index 2146: pemerintah kabupaten pakpak bharat
# processing index 2147: komite olahraga nasional indonesia
# processing index 2148: kacab bri samarinda 1
# processing index 2149: mandai prima
# processing index 2150: pt asabri persero
# processing index 2151: bni divisi pengelolaan jaringan
# processing index 2152: blibli
# processing index 2153: kpsp setia kawan
# processing index 2154: am huawei indonesia
# processing index 2155: gubernur kalimantan barat
# processing index 2156: pt cahaya maha pertiwi
# processing index 2157: pemkab sintang
# processing index 2158: desa ginuk
# processing index 2159: direktur utama pt bni
# processing index 2160: tidak diketahui pelapor

# %%
predictions.head()
# Out:
#               nama_instansi                                    candidates
# 0       kementerian kominfo                                       kominfo
# 1                tidak tahu  Bukan instansi BUMN, Kementerian, Pemerintah
# 2  pt maybank indonesia tbk                                        pt bni
# 3                   rekanan  Bukan instansi BUMN, Kementerian, Pemerintah
# 4              kemko marves  Bukan instansi BUMN, Kementerian, Pemerintah

# %%
predictions
# Out:
#                  nama_instansi                                    candidates
# 0          kementerian kominfo                                       kominfo
# 1                   tidak tahu  Bukan instansi BUMN, Kementerian, Pemerintah
# 2     pt maybank indonesia tbk                                        pt bni
# 3                      rekanan  Bukan instansi BUMN, Kementerian, Pemerintah
# 4                 kemko marves  Bukan instansi BUMN, Kementerian, Pemerintah
# ...                        ...                                           ...
# 2156    pt cahaya maha pertiwi                                        pt pii
# 2157            pemkab sintang                                pemkab sintang
# 2158                desa ginuk  Bukan instansi BUMN, Kementerian, Pemerintah
# 2159     direktur utama pt bni                         direktur utama pt bni
# 2160   tidak diketahui pelapor  Bukan instansi BUMN, Kementerian, Pemerintah
#
# [2160 rows x 2 columns]

# %%
predictions.groupby('candidates').count().sort_values('nama_instansi', ascending=False)
# Out:
#                                               nama_instansi
# candidates
# Bukan instansi BUMN, Kementerian, Pemerintah           1181
# pt inti                                                  23
# pt reindo                                                18
# pt amarta                                                16
# pt bni                                                   15
# ...                                                     ...
# pemerintah kabupaten boyolali                             1
# pemerintah kabupaten bone bolango                         1
# pemerintah kabupaten bone                                 1
# pemerintah kabupaten bombana                              1
# virama karya                                              1
#
# [561 rows x 1 columns]

# %% [markdown]
# ## Get true references for each candidate returned

# %%
train = pd.read_csv('../indexing/data/splitted_data/v2/train.csv')
val = pd.read_csv('../indexing/data/splitted_data/v2/val.csv')
test = pd.read_csv('../indexing/data/splitted_data/v2/test.csv')

# %%
df_all = pd.concat([train, val, test])

# %%
df_all.reset_index(drop=True, inplace=True)

# %%
df_all
# Out:
#                                       instansi status  \
# 0          lembaga pembiayaan ekspor indonesia    yes
# 1          lembaga pembiayaan ekspor indonesia    yes
# 2          lembaga pembiayaan ekspor indonesia    yes
# 3          lembaga pembiayaan ekspor indonesia    yes
# 4          lembaga pembiayaan ekspor indonesia     no
# ...                                        ...    ...
# 4340                              pt indofarma    yes
# 4341                              pt indofarma     no
# 4342   pt kereta api indonesia (persero) (kai)     no
# 4343  pt dok dan perkapalan surabaya (persero)     no
# 4344  pt dok dan perkapalan surabaya (persero)     no
#
#                         reference
# 0       lembaga pembiayaan ekspor
# 1                            lpei
# 2        lembaga ekspor indonesia
# 3     pembiayaan ekspor indonesia
# 4            pembiayaan indonesia
# ...                           ...
# 4340                    indofarma
# 4341                          igm
# 4342                   kereta api
# 4343                pt perkapalan
# 4344                       pt dok
#
# [4345 rows x 3 columns]

# %%
df_all['cln_instansi'] = df_all['instansi'].str.replace('/', ' ')
df_all['cln_instansi'] = df_all['cln_instansi'].str.replace('[^\w\s]','',regex=True)

# %%
df_all['cln_reference'] = df_all['reference'].str.replace('/', ' ')
df_all['cln_reference'] = df_all['cln_reference'].str.replace('[^\w\s]','',regex=True)

# %%
df_all = df_all.drop(['reference', 'instansi'], axis=1)
df_all = df_all.rename(columns={'cln_reference':'reference', 'cln_instansi':'instansi'})

# %%
df_all
# Out:
#      status                                instansi  \
# 0       yes     lembaga pembiayaan ekspor indonesia
# 1       yes     lembaga pembiayaan ekspor indonesia
# 2       yes     lembaga pembiayaan ekspor indonesia
# 3       yes     lembaga pembiayaan ekspor indonesia
# 4        no     lembaga pembiayaan ekspor indonesia
# ...     ...                                     ...
# 4340    yes                            pt indofarma
# 4341     no                            pt indofarma
# 4342     no     pt kereta api indonesia persero kai
# 4343     no  pt dok dan perkapalan surabaya persero
# 4344     no  pt dok dan perkapalan surabaya persero
#
#                         reference
# 0       lembaga pembiayaan ekspor
# 1                            lpei
# 2        lembaga ekspor indonesia
# 3     pembiayaan ekspor indonesia
# 4            pembiayaan indonesia
# ...                           ...
# 4340                    indofarma
# 4341                          igm
# 4342                   kereta api
# 4343                pt perkapalan
# 4344                       pt dok
#
# [4345 rows x 3 columns]

# %%
df_all[df_all['instansi'].str.startswith('kementerian agraria dan tata ruang')]['instansi'].iloc[0]
# Out:
# 'kementerian agraria dan tata ruang badan pertanahan nasional bpn'

# %%
def get_official_instansi(nama_instansi):
    official = ''
    try:
        official = df_all[(df_all['reference']==nama_instansi) & (df_all['status']=='yes')]['instansi'].values[0]
    except:
        official = df_all[(df_all['instansi']==nama_instansi)]['instansi'].values[0]
    return official

# %%
get_official_instansi('badan pertanahan nasional')
# Out:
# 'kementerian agraria dan tata ruang badan pertanahan nasional bpn'

# %%
def get_true_references(nama_instansi):
    official_instansi = get_official_instansi(nama_instansi)
    true_refs = [official_instansi]
    true_references = df_all[(df_all['instansi']==official_instansi) & (df_all['status']=='yes')]['reference']
    for i in true_references:
        true_refs.append(i)
    return true_refs

# %%
get_true_references('badan pertanahan nasional')
# Out:
# ['kementerian agraria dan tata ruang badan pertanahan nasional bpn',
#  'kementerian agraria',
#  'kementerian tata ruang',
#  'kementerian badan pertanahan nasional',
#  'badan pertanahan nasional',
#  'atr',
#  'bpn',
#  'atr bpn']

# %% [markdown]
# ### Loop through

# %%
predicted_status = []
true_references = []

# %%
for index, row in predictions.iterrows():
    nama_inst = row[['candidates']].values[0]
    
    try:
        if nama_inst == 'Bukan instansi BUMN, Kementerian, Pemerintah':
            true_references.append([])
            predicted_status.append('yes')
        else:
            true_ref = get_true_references(nama_inst)
            true_references.append(true_ref)
            test_instansi = row[['nama_instansi']].values[0]
            if test_instansi in true_ref:
                predicted_status.append('yes')
            else:
                predicted_status.append('no')
    except:
        print(nama_inst)
        print(index)
        predicted_status.append('no')
        true_references.append([])
        continue

# %%
predictions['status_from_references'] = predicted_status
predictions['true_references'] = true_references

# %%
predictions
# Out:
#                  nama_instansi                                    candidates  \
# 0          kementerian kominfo                                       kominfo
# 1                   tidak tahu  Bukan instansi BUMN, Kementerian, Pemerintah
# 2     pt maybank indonesia tbk                                        pt bni
# 3                      rekanan  Bukan instansi BUMN, Kementerian, Pemerintah
# 4                 kemko marves  Bukan instansi BUMN, Kementerian, Pemerintah
# ...                        ...                                           ...
# 2156    pt cahaya maha pertiwi                                        pt pii
# 2157            pemkab sintang                                pemkab sintang
# 2158                desa ginuk  Bukan instansi BUMN, Kementerian, Pemerintah
# 2159     direktur utama pt bni                         direktur utama pt bni
# 2160   tidak diketahui pelapor  Bukan instansi BUMN, Kementerian, Pemerintah
#
#      status_from_references                                    true_references
# 0                        no  [kementerian komunikasi dan informatika, kemen...
# 1                       yes                                                 []
# 2                        no  [pt bank negara indonesia persero tbk bni, pt ...
# 3                       yes                                                 []
# 4                       yes                                                 []
# ...                     ...                                                ...
# 2156                     no  [pt penjaminan infrastruktur indonesia persero...
# 2157                    yes  [pemerintah kabupaten sintang, pemkab sintang,...
# 2158                    yes                                                 []
# 2159                    yes  [pt bank negara indonesia persero tbk bni, pt ...
# 2160                    yes                                                 []
#
# [2160 rows x 4 columns]

# %%
predictions.groupby('status_from_references').count()[['nama_instansi']]
# Out:
#                         nama_instansi
# status_from_references
# no                                601
# yes                              1559

# %%
predictions.to_csv('./eval/lev_performances/exp1a-2b.csv')

# %% [markdown]
# ## Manually Checked

# %%
import pandas as pd

# %%
checks_completed = pd.read_csv('./eval/lev_performances/exp1a-2b_checked_revised.csv', sep=';')

# %%
checks_completed
# Out:
#       Column1             nama_instansi  \
# 0           0       kementerian kominfo
# 1           1                tidak tahu
# 2           2  pt maybank indonesia tbk
# 3           3                   rekanan
# 4           4              kemko marves
# ...       ...                       ...
# 2155     2156    pt cahaya maha pertiwi
# 2156     2157            pemkab sintang
# 2157     2158                desa ginuk
# 2158     2159     direktur utama pt bni
# 2159     2160   tidak diketahui pelapor
#
#                                         candidates status_manual  \
# 0                                          kominfo           yes
# 1     Bukan instansi BUMN, Kementerian, Pemerintah           yes
# 2                                           pt bni            no
# 3     Bukan instansi BUMN, Kementerian, Pemerintah           yes
# 4     Bukan instansi BUMN, Kementerian, Pemerintah            no
# ...                                            ...           ...
# 2155                                        pt pii            no
# 2156                                pemkab sintang           yes
# 2157  Bukan instansi BUMN, Kementerian, Pemerintah           yes
# 2158                         direktur utama pt bni           yes
# 2159  Bukan instansi BUMN, Kementerian, Pemerintah           yes
#
#      status_from_references                                    true_references
# 0                        no  ['kementerian komunikasi dan informatika', 'ke...
# 1                       yes                                                 []
# 2                        no  ['pt bank negara indonesia persero tbk bni', '...
# 3                       yes                                                 []
# 4                       yes                                                 []
# ...                     ...                                                ...
# 2155                     no  ['pt penjaminan infrastruktur indonesia perser...
# 2156                    yes  ['pemerintah kabupaten sintang', 'pemkab sinta...
# 2157                    yes                                                 []
# 2158                    yes  ['pt bank negara indonesia persero tbk bni', '...
# 2159                    yes                                                 []
#
# [2160 rows x 6 columns]

# %% [markdown]
# ## Matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
status_d = {
    'no': 0,
    'yes': 1
}
copied = checks_completed.copy()
copied['status_manual'] = copied['status_manual'].map(status_d)
copied['status_from_references'] = copied['status_from_references'].map(status_d)

# %%
y_true = copied['status_manual']
y_pred = copied['status_from_references']

# %%
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm/np.sum(cm), annot=True, fmt='.2%', cmap='Blues')
plt.xlabel('Status From Reference')
plt.ylabel('Status Manual')
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
agg = checks_completed.groupby('status_manual').count()[['nama_instansi']]

# %%
agg.plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='status_manual'>

# %%
copied[copied['status_manual']==1]
# Out:
#       Column1                               nama_instansi  \
# 0           0                         kementerian kominfo
# 1           1                                  tidak tahu
# 3           3                                     rekanan
# 5           5                      smk negeri 1 jogonalan
# 6           6  kantor pelayanan pajak pratama medan barat
# ...       ...                                         ...
# 2153     2154                         am huawei indonesia
# 2156     2157                              pemkab sintang
# 2157     2158                                  desa ginuk
# 2158     2159                       direktur utama pt bni
# 2159     2160                     tidak diketahui pelapor
#
#                                         candidates  status_manual  \
# 0                                          kominfo              1
# 1     Bukan instansi BUMN, Kementerian, Pemerintah              1
# 3     Bukan instansi BUMN, Kementerian, Pemerintah              1
# 5     Bukan instansi BUMN, Kementerian, Pemerintah              1
# 6     Bukan instansi BUMN, Kementerian, Pemerintah              1
# ...                                            ...            ...
# 2153  Bukan instansi BUMN, Kementerian, Pemerintah              1
# 2156                                pemkab sintang              1
# 2157  Bukan instansi BUMN, Kementerian, Pemerintah              1
# 2158                         direktur utama pt bni              1
# 2159  Bukan instansi BUMN, Kementerian, Pemerintah              1
#
#       status_from_references  \
# 0                          0
# 1                          1
# 3                          1
# 5                          1
# 6                          1
# ...                      ...
# 2153                       1
# 2156                       1
# 2157                       1
# 2158                       1
# 2159                       1
#
#                                         true_references
# 0     ['kementerian komunikasi dan informatika', 'ke...
# 1                                                    []
# 3                                                    []
# 5                                                    []
# 6                                                    []
# ...                                                 ...
# 2153                                                 []
# 2156  ['pemerintah kabupaten sintang', 'pemkab sinta...
# 2157                                                 []
# 2158  ['pt bank negara indonesia persero tbk bni', '...
# 2159                                                 []
#
# [1607 rows x 6 columns]

# %%
copied[copied['status_manual']==0]
# Out:
#       Column1                     nama_instansi  \
# 2           2          pt maybank indonesia tbk
# 4           4                      kemko marves
# 8           8     pt sawit sumbermas sarana tbk
# 9           9             pt nusa niaga perkasa
# 28         28    kantor atr   bpn kota salatiga
# ...       ...                               ...
# 2126     2127                            pt kmi
# 2128     2129                pt asuransi aswata
# 2141     2142  pt yobel utama seafood indonesia
# 2154     2155         gubernur kalimantan barat
# 2155     2156            pt cahaya maha pertiwi
#
#                                         candidates  status_manual  \
# 2                                           pt bni              0
# 4     Bukan instansi BUMN, Kementerian, Pemerintah              0
# 8                                          pt sier              0
# 9                                          pt sier              0
# 28                                      kantor pos              0
# ...                                            ...            ...
# 2126                                pt kimia farma              0
# 2128                                        pt rni              0
# 2141                                 pos indonesia              0
# 2154  Bukan instansi BUMN, Kementerian, Pemerintah              0
# 2155                                        pt pii              0
#
#       status_from_references  \
# 2                          0
# 4                          1
# 8                          0
# 9                          0
# 28                         0
# ...                      ...
# 2126                       0
# 2128                       0
# 2141                       0
# 2154                       1
# 2155                       0
#
#                                         true_references
# 2     ['pt bank negara indonesia persero tbk bni', '...
# 4                                                    []
# 8     ['pt surabaya industrial estate rungkut', 'sur...
# 9     ['pt surabaya industrial estate rungkut', 'sur...
# 28    ['pt pos indonesia persero', 'pt pos indonesia...
# ...                                                 ...
# 2126  ['pt kimia farma persero tbk', 'pt kimia farma...
# 2128  ['pt rajawali nusantara indonesia persero', 'p...
# 2141  ['pt pos indonesia persero', 'pt pos indonesia...
# 2154                                                 []
# 2155  ['pt penjaminan infrastruktur indonesia perser...
#
# [553 rows x 6 columns]

# %%
1607/(1607+553)
# Out:
# 0.7439814814814815

# %%
tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

# %%
print(tn, fp, fn, tp)
# Out:
# 440 113 161 1446

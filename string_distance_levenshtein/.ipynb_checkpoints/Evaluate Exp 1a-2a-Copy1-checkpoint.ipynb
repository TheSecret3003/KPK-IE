# %%
import pandas as pd
import numpy as np
from get_similar_entity import get_similar_entity
from evaluation import clean_test_df, get_similar_entity_1a

# %% [markdown]
# ## Prep test data

# %%
test_data = pd.read_csv('./eval/test_data/test.csv')

# %%
test_data.head()
# Out:
#                                             instansi status  \
# 0  kementerian agraria dan tata ruang/badan perta...    yes
# 1  kementerian agraria dan tata ruang/badan perta...    yes
# 2  kementerian agraria dan tata ruang/badan perta...    yes
# 3  kementerian agraria dan tata ruang/badan perta...    yes
# 4  kementerian agraria dan tata ruang/badan perta...    yes
#
#                                reference
# 0                    kementerian agraria
# 1                 kementerian tata ruang
# 2  kementerian badan pertanahan nasional
# 3              badan pertanahan nasional
# 4                                    atr

# %%
test_data2 = test_data[['reference']]

# %%
test_data2 = test_data2.rename(columns={'reference': 'nama_instansi'})

# %%
test_data2
# Out:
#                              nama_instansi
# 0                      kementerian agraria
# 1                   kementerian tata ruang
# 2    kementerian badan pertanahan nasional
# 3                badan pertanahan nasional
# 4                                      atr
# ..                                     ...
# 907                              indofarma
# 908                                    igm
# 909                             kereta api
# 910                          pt perkapalan
# 911                                 pt dok
#
# [912 rows x 1 columns]

# %%
test_data2 = clean_test_df(test_data2)

# %%
test_data2.head()
# Out:
#                            nama_instansi
# 0                    kementerian agraria
# 1                 kementerian tata ruang
# 2  kementerian badan pertanahan nasional
# 3              badan pertanahan nasional
# 4                                    atr

# %%
test_data2.isnull().sum()
# Out:
# nama_instansi    0
# dtype: int64

# %% [markdown]
# duplicate removed

# %%
test_data2.shape
# Out:
# (757, 1)

# %%
test_data2
# Out:
#                              nama_instansi
# 0                      kementerian agraria
# 1                   kementerian tata ruang
# 2    kementerian badan pertanahan nasional
# 3                badan pertanahan nasional
# 4                                      atr
# ..                                     ...
# 752                              indofarma
# 753                                    igm
# 754                             kereta api
# 755                          pt perkapalan
# 756                                 pt dok
#
# [757 rows x 1 columns]

# %% [markdown]
# ## Predictions

# %%
predictions = get_similar_entity_1a(test_data2, reference_version='v2')
# Out:
# processing index 0: kementerian agraria
# processing index 1: kementerian tata ruang
# processing index 2: kementerian badan pertanahan nasional
# processing index 3: badan pertanahan nasional
# processing index 4: atr
# processing index 5: bpn
# processing index 6: atr bpn
# processing index 7: agraria
# processing index 8: agraria dan tata ruang
# processing index 9: tata ruang
# processing index 10: kementerian energi
# processing index 11: kementerian sumber daya mineral
# processing index 12: esdm
# processing index 13: energi
# processing index 14: sumber daya mineral
# processing index 15: kementerian energi dan sumber daya mineral
# processing index 16: kementerian hukum
# processing index 17: kementerian hukum dan ham
# processing index 18: kementerian ham
# processing index 19: kementerian hak asasi manusia
# processing index 20: hukum dan ham
# processing index 21: hukum
# processing index 22: ham
# processing index 23: kemenkumham
# processing index 24: kemenkes
# processing index 25: kesehatan
# processing index 26: kementerian kemenkes
# processing index 27: kementerian komunikasi
# processing index 28: kementerian informatika
# processing index 29: kominfo
# processing index 30: informatika
# processing index 31: komunikasi
# processing index 32: komunikasi dan informatika
# processing index 33: kemlu
# processing index 34: kemlu ri
# processing index 35: luar negeri
# processing index 36: kementrian dalam negeri
# processing index 37: kementrian bumn
# processing index 38: kemen bumn
# processing index 39: bumn
# processing index 40: badan usaha milik negara
# processing index 41: kemenparekraf
# processing index 42: kemenparekraf ri
# processing index 43: dinas pariwisata dan kebudayaan kota bogor
# processing index 44: dinas kebudayaan dan pariwisata kota bandung
# processing index 45: kemen pppa
# processing index 46: kementrian pp  pa
# processing index 47: pemberdayaan perempuan
# processing index 48: komisi perlindungan anak indonesia
# processing index 49: kemhan
# processing index 50: departemen pertahanan
# processing index 51: badan pertahanan nasional
# processing index 52: universitas pertahanan
# processing index 53: bpk
# processing index 54: badan pemeriksa keuangan
# processing index 55: bpkp
# processing index 56: kementerian keuangan
# processing index 57: ky
# processing index 58: komisi yudisial ky
# processing index 59: anggota dpr ri komisi ix
# processing index 60: komisi penyiaran indonesia
# processing index 61: kementrian investasi bkpm
# processing index 62: kementrian investasi
# processing index 63: bbkpm surakarta
# processing index 64: dinas penanaman modal dan pelayanan terpadu satu pintu
# processing index 65: bppt
# processing index 66: perwakilan bppt
# processing index 67: kementerian pendidikan kebudayaan riset dan teknologi
# processing index 68: badan pengkajian kebijakan iklim dan mutu industri
# processing index 69: badan pengusahaan batam bp batam
# processing index 70: bp batam
# processing index 71: pemerintah kota batam
# processing index 72: universitas batam
# processing index 73: bssn
# processing index 74: badan siber dan sandi negara
# processing index 75: pt beritakota media siber beritakotaid
# processing index 76: universitas siber asia
# processing index 77: kpu kabupaten memberamo raya
# processing index 78: komisi pemilihan umum kabupaten fakfak
# processing index 79: kpu bc tipe c soekarno hatta
# processing index 80: kpu bc tipe b batam
# processing index 81: lembaga ketahanan nasional
# processing index 82: lemhannas ri
# processing index 83: dewan ketahanan nasional wantannas
# processing index 84: lembaga penerbangan dan antariksa nasional lapan
# processing index 85: badan pengelola keuangan haji
# processing index 86: bpkh
# processing index 87: badan pengelola keuangan
# processing index 88: badan pengelola haji
# processing index 89: badan penyelenggara jaminan sosial ketenagakerjaan
# processing index 90: bpjamsostek
# processing index 91: bpjs ketenagakerjaan
# processing index 92: bpjs
# processing index 93: badan penyelenggara jaminan sosial
# processing index 94: bank indonesia bi
# processing index 95: bi
# processing index 96: bank internasional indonesia
# processing index 97: pemerintahan gianyar
# processing index 98: pemerintah kabupaten
# processing index 99: gianyar
# processing index 100: pemkab gianyar
# processing index 101: pemkab
# processing index 102: pemerintahan tabanan
# processing index 103: tabanan
# processing index 104: pemkab tabanan
# processing index 105: pemkab cilegon
# processing index 106: cilegon
# processing index 107: pemerintah cilegon
# processing index 108: pemkab tangerang selatan
# processing index 109: tangerang selatan
# processing index 110: pemkot tangerang
# processing index 111: pemkab tangsel
# processing index 112: pemerintah tangerang selatan
# processing index 113: pemkab kaur
# processing index 114: kaur
# processing index 115: pemerintah kaur
# processing index 116: pemkab kepahiang
# processing index 117: kepahiang
# processing index 118: pemerintah kepahiang
# processing index 119: pemkot bengkulu
# processing index 120: bengkulu
# processing index 121: pemprov bengkulu
# processing index 122: pemerintah bengkulu
# processing index 123: pemkot jakarta pusat
# processing index 124: pemerintah kota administrasi jakarta pusat
# processing index 125: pemerintah kota jakarta barat
# processing index 126: pemerintah kota jakarta timur
# processing index 127: pemkab tebo
# processing index 128: tebo
# processing index 129: pemerintah tebo
# processing index 130: pemkab bandung barat
# processing index 131: bandung barat
# processing index 132: pemerintah bandung barat
# processing index 133: pemkab bogor
# processing index 134: bogor
# processing index 135: pemerintah bogor
# processing index 136: pemkab ciamis
# processing index 137: ciamis
# processing index 138: pemerintah ciamis
# processing index 139: pemkab cirebon
# processing index 140: cirebon
# processing index 141: pemerintah cirebon
# processing index 142: pemkab karawang
# processing index 143: karawang
# processing index 144: pemerintah karawang
# processing index 145: pemkot bekasi
# processing index 146: bekasi
# processing index 147: pemkot bogor
# processing index 148: pemprov jawa barat
# processing index 149: jawa barat
# processing index 150: pemerintah jawa barat
# processing index 151: pemprov jabar
# processing index 152: pemkab blora
# processing index 153: blora
# processing index 154: pemerintah blora
# processing index 155: pemkab boyolali
# processing index 156: boyolali
# processing index 157: pemerintah boyolali
# processing index 158: pemkab brebes
# processing index 159: brebes
# processing index 160: pemerintah brebes
# processing index 161: pemkab kebumen
# processing index 162: kebumen
# processing index 163: pemerintah kebumen
# processing index 164: pemkab magelang
# processing index 165: magelang
# processing index 166: pemerintah magelang
# processing index 167: pemkab pemalang
# processing index 168: pemalang
# processing index 169: pemerintah pemalang
# processing index 170: pemkab sragen
# processing index 171: sragen
# processing index 172: pemerintah sragen
# processing index 173: pemkab sukoharjo
# processing index 174: sukoharjo
# processing index 175: pemerintah sukoharjo
# processing index 176: pemkab temanggung
# processing index 177: temanggung
# processing index 178: pemerintah temanggung
# processing index 179: pemkot magelang
# processing index 180: pemkot pekalongan
# processing index 181: pekalongan
# processing index 182: pemkab jombang
# processing index 183: jombang
# processing index 184: pemerintah jombang
# processing index 185: pemkab lamongan
# processing index 186: lamongan
# processing index 187: pemerintah lamongan
# processing index 188: pemkab malang
# processing index 189: malang
# processing index 190: pemerintah malang
# processing index 191: pemkab magetan
# processing index 192: magetan
# processing index 193: pemerintah magetan
# processing index 194: pemkab pacitan
# processing index 195: pacitan
# processing index 196: pemerintah pacitan
# processing index 197: pemkab tulungagung
# processing index 198: tulungagung
# processing index 199: pemerintah tulungagung
# processing index 200: pemkot surabaya
# processing index 201: surabaya
# processing index 202: pemerintah surabaya
# processing index 203: pemkab ketapang
# processing index 204: ketapang
# processing index 205: pemerintah ketapang
# processing index 206: pemkab kubu raya
# processing index 207: kubu raya
# processing index 208: pemerintah kubu raya
# processing index 209: pemkab landak
# processing index 210: landak
# processing index 211: pemerintah landak
# processing index 212: pemkab sambas
# processing index 213: sambas
# processing index 214: pemerintah sambas
# processing index 215: pemkot singkawang
# processing index 216: singkawang
# processing index 217: pemerintah singkawang
# processing index 218: pemprov kalimantan barat
# processing index 219: kalimantan barat
# processing index 220: pemerintah kalimantan barat
# processing index 221: pemprov kalbar
# processing index 222: pemkab barito kuala
# processing index 223: barito kuala
# processing index 224: pemerintah barito kuala
# processing index 225: pemkab hulu sungai selatan
# processing index 226: hulu sungai selatan
# processing index 227: pemerintah hulu sungai selatan
# processing index 228: pemkab aceh utara
# processing index 229: pemprov nanggroe aceh darusalam
# processing index 230: pemerintah provinsi nanggroe aceh darusalam
# processing index 231: pemkot banda aceh
# processing index 232: pemerintah kabupaten aceh utara
# processing index 233: pemkab aceh barat daya
# processing index 234: pemerintah kabupaten aceh barat daya
# processing index 235: pemkab aceh tengah
# processing index 236: pemerintah kabupaten aceh tengah
# processing index 237: pemerintah kota banda aceh
# processing index 238: pemerintah kabupaten aceh tenggara
# processing index 239: pemkab aceh besar
# processing index 240: pemerintah kabupaten aceh tamiang
# processing index 241: pemerintah kabupaten aceh timur
# processing index 242: pemerintah kabupaten aceh barat
# processing index 243: pemerintah kabupaten aceh singkil
# processing index 244: pemkab aceh tenggara
# processing index 245: pemkab aceh timur
# processing index 246: pemkab aceh selatan
# processing index 247: pemkab aceh singkil
# processing index 248: pemerintah kabupaten aceh jaya
# processing index 249: pemkab aceh tamiang
# processing index 250: pemerintah kabupaten aceh selatan
# processing index 251: pemkab aceh barat
# processing index 252: pemkab aceh jaya
# processing index 253: pemerintah kabupaten aceh besar
# processing index 254: pemerintah kabupaten barito selatan
# processing index 255: pemkab barito utara
# processing index 256: pemerintah kabupaten barito utara
# processing index 257: pemkab barito timur
# processing index 258: pemkab barito selatan
# processing index 259: pemkab biak numfor
# processing index 260: pulau biak
# processing index 261: jalan bulungan
# processing index 262: jl bulungan
# processing index 263: desa bulungan
# processing index 264: pemkab bulungan
# processing index 265: pa dompu
# processing index 266: pengadilan agama dompu
# processing index 267: pemkab dompu
# processing index 268: kementerian agama kabupaten dompu
# processing index 269: kemenag kabupaten dompu
# processing index 270: pemkab ende
# processing index 271: keuskupan agung ende
# processing index 272: pemerintah kabupaten sula
# processing index 273: pemkab kepulauan sula
# processing index 274: pemkab kepulauan anambas
# processing index 275: pemerintah kabupaten kepulauan anambas
# processing index 276: pemkab kepulauan yapen
# processing index 277: pemkab kepulauan aru
# processing index 278: pemerintah kabupaten kepulauan aru
# processing index 279: pemerintah kabupaten kepulauan yapen
# processing index 280: pemkab sula
# processing index 281: pemkab kotawaringin barat
# processing index 282: pemerintah kabupaten kotawaringin timur
# processing index 283: pemkab kotawaringin timur
# processing index 284: pemerintah kabupaten lampung timur
# processing index 285: pemkab lampung barat
# processing index 286: pemkab lampung timur
# processing index 287: pemerintah kota bandar lampung
# processing index 288: pemkot bandar lampung
# processing index 289: pemerintah kabupaten lampung selatan
# processing index 290: pemkab lampung selatan
# processing index 291: pemprov lampung
# processing index 292: pemerintah kabupaten lampung utara
# processing index 293: pemkab lampung utara
# processing index 294: pemkab lampung tengah
# processing index 295: pemerintah provinsi lampung
# processing index 296: pemerintah kabupaten lampung tengah
# processing index 297: pemerintah kabupaten pidie jaya
# processing index 298: pemkab pidie jaya
# processing index 299: pemkab lanny jaya
# processing index 300: pemerintah kabupaten puncak jaya
# processing index 301: pemkab intan jaya
# processing index 302: pemerintah kabupaten intan jaya
# processing index 303: pemkab puncak jaya
# processing index 304: pemerintah kabupaten lombok tengah
# processing index 305: pemkab lombok tengah
# processing index 306: pemkab lombok barat
# processing index 307: pemerintah kabupaten lombok utara
# processing index 308: pemkab lombok utara
# processing index 309: pemkab lombok timur
# processing index 310: pemerintah kabupaten lombok timur
# processing index 311: pemerintah kabupaten lombok barat
# processing index 312: partai ummat kabupaten nabire
# processing index 313: pemkab nabire
# processing index 314: bps kabupaten nabire
# processing index 315: badan pusat statistik kabupaten nabire
# processing index 316: natgeo
# processing index 317: pemkab nagekeo
# processing index 318: laut natuna
# processing index 319: pemkab natuna
# processing index 320: pemerintah kabupaten pasuruan
# processing index 321: pemkab pasuruan
# processing index 322: pemkab nunukan
# processing index 323: pemkab sarmi
# processing index 324: pemerintah kabupaten seram
# processing index 325: pemkab seram
# processing index 326: pemkab seram bagian timur
# processing index 327: pemkab seram bagian barat
# processing index 328: pemkab seram barat
# processing index 329: pemerintah kabupaten seram barat
# processing index 330: pemerintah kabupaten seram bagian timur
# processing index 331: pemerintah kabupaten seram timur
# processing index 332: pemkab seram timur
# processing index 333: kpu kabupaten sikka
# processing index 334: pemkab sikka
# processing index 335: bps kabupaten sikka
# processing index 336: komisi pemilihan umum kabupaten sikka
# processing index 337: badan pusat statistuk kabupaten sikka
# processing index 338: bps kabupaten simeulue
# processing index 339: pemkab simeulue
# processing index 340: pulau simeulue
# processing index 341: badan pusat statistik kabupaten simeulue
# processing index 342: pemkab tanah bumbu
# processing index 343: pemerintah kabupaten tanah laut
# processing index 344: pemkab tana tidung
# processing index 345: pemkab tanah laut
# processing index 346: pemerintah kabupaten tanah bumbu
# processing index 347: pemerintah ktt
# processing index 348: bps kabupaten tolikara
# processing index 349: pemkab tolikara
# processing index 350: badan pusat statistik tolikara
# processing index 351: bps tolikara
# processing index 352: badan pusat statistik kabupaten tolikara
# processing index 353: pemkab yahukimo
# processing index 354: pemkab yalimo
# processing index 355: pemerintah kabupaten yalimo
# processing index 356: pemerintah kota mataram
# processing index 357: batan
# processing index 358: pemkot mataram
# processing index 359: pemkot batam
# processing index 360: pemkot ternate
# processing index 361: kesultanan ternate
# processing index 362: pemprov kalimantan selatan
# processing index 363: pemerintah provinsi kalsel
# processing index 364: pemprov kalsel
# processing index 365: pemerintah provinsi kalimantan tengah
# processing index 366: pemprov kalimantan utara
# processing index 367: pemerintah provinsi kalimantan timur
# processing index 368: pemprov kalimantan timur
# processing index 369: pemprov kalimantan tengah
# processing index 370: pemerintah provinsi kalimantan utara
# processing index 371: pemkab bangka
# processing index 372: pemprov kepulauan babel
# processing index 373: pemerintah provinsi kepulauan babel
# processing index 374: pemerintah provinsi babel
# processing index 375: pemprov babel
# processing index 376: pemerintah kabupaten bangka
# processing index 377: pemprov bangka belitung
# processing index 378: pemerintah provinsi bangka belitung
# processing index 379: pemprov kepulauan bangka belitung
# processing index 380: pemerintah kabupaten kepulauan talaud
# processing index 381: pemerintah kabupaten banggai laut
# processing index 382: pemkab banggai laut
# processing index 383: pemkab banggai
# processing index 384: pemkab banggai kepulauan
# processing index 385: pemerintah kabupaten banggai
# processing index 386: pemerintah kabupaten kepulauan sangihe
# processing index 387: pemerintah kabupaten kepulauan selayar
# processing index 388: pemkab kepulauan selayar
# processing index 389: pemerintah kabupaten konawe kepulauan
# processing index 390: pemkab konawe kepulauan
# processing index 391: pemkab kepulauan sangihe
# processing index 392: pemkab kepulauan siau tagulandang biaro
# processing index 393: pemerintah kabupaten kepulauan mentawai
# processing index 394: pemkab kepulauan mentawai
# processing index 395: pemkab pangkajene kepulauan
# processing index 396: pemerintah kabupaten pangkajene kepulauan
# processing index 397: pemkab kepulauan meranti
# processing index 398: pemerintah kabupaten kepulauan meranti
# processing index 399: pemkab kepulauan talaud
# processing index 400: pemerintah kabupaten kepulauan siau tagulandang biaro
# processing index 401: pemerintah kabupaten bolaang mongondow timur
# processing index 402: pemkab bolaang mongondow timur
# processing index 403: pemerintah kabupaten bolaang mongondow selatan
# processing index 404: pemkab bolaang mongondow
# processing index 405: pemkab bolaang mongondow selatan
# processing index 406: pemerintah kabupaten bolaang mongondow utara
# processing index 407: pemkab bolaang mongondow utara
# processing index 408: pemerintah kabupaten buton
# processing index 409: pemkab buton selatan
# processing index 410: pemerintah kabupaten buton selatan
# processing index 411: pemkab buton utara
# processing index 412: pemerintah kabupaten buton utara
# processing index 413: pemkab buton
# processing index 414: pemkab buton tengah
# processing index 415: pemkab dairi
# processing index 416: pemerintah kabupaten deiyai
# processing index 417: pemerintah kabupaten ketapang
# processing index 418: pemkab enrekang
# processing index 419: pemerintah kabupaten jombang
# processing index 420: pemkab humbang hasundutan
# processing index 421: pemkab indragiri hulu
# processing index 422: pemerintah kabupaten indragiri hulu
# processing index 423: pemkab indragiri hilir
# processing index 424: pemerintah kabupaten konawe utara
# processing index 425: pemkab konawe
# processing index 426: pemerintah kabupaten konawe selatan
# processing index 427: pemerintah kabupaten konawe
# processing index 428: pemkab konawe selatan
# processing index 429: pemerintah kabupaten banggai kepulauan
# processing index 430: pemkab konawe utara
# processing index 431: pemerintah kabupaten labuhanbatu utara
# processing index 432: pemkab labuhanbatu utara
# processing index 433: pemkab labuhanbatu
# processing index 434: pemerintah kabupaten labuhanbatu selatan
# processing index 435: pemkab labuhanbatu selatan
# processing index 436: pemerintah kabupaten labuhanbatu
# processing index 437: pemkab luwu utara
# processing index 438: pemerintah kabupaten luwu utara
# processing index 439: pemerintah kabupaten luwu timur
# processing index 440: pemkab luwu timur
# processing index 441: pemkab luwu
# processing index 442: pemkab maros
# processing index 443: pemkab muaro
# processing index 444: pemerintah kabupaten muaro
# processing index 445: pemkab karo
# processing index 446: pemerintah kabupaten karo
# processing index 447: pemkab muna barat
# processing index 448: pemerintah kabupaten muna barat
# processing index 449: pemkab maybrat
# processing index 450: pemerintah kabupaten minahasa utara
# processing index 451: pemerintah kabupaten minahasa selatan
# processing index 452: pemkab minahasa tenggara
# processing index 453: pemerintah kabupaten minahasa tenggara
# processing index 454: pemkab minahasa utara
# processing index 455: pemkab minahasa
# processing index 456: pemkab minahasa selatan
# processing index 457: pemerintah kabupaten minahasa
# processing index 458: pemkab morowali utara
# processing index 459: pemkab morowali
# processing index 460: pemerintah kabupaten morowali utara
# processing index 461: pemerintah kabupaten musi
# processing index 462: pemkab muna
# processing index 463: pemerintah kabupaten muna
# processing index 464: pemerintah kabupaten musi banyuasin
# processing index 465: pemkab musi rawas
# processing index 466: pemerintah kabupaten musi rawas
# processing index 467: pemkab musi banyuasin
# processing index 468: pemkab musi rawas utara
# processing index 469: pemerintah kabupaten nias selatan
# processing index 470: pemkab nias selatan
# processing index 471: pemerintah kabupaten nias barat
# processing index 472: pemkab nias barat
# processing index 473: pemerintah kabupaten nias
# processing index 474: pemkab nias utara
# processing index 475: pemkab nias
# processing index 476: pemerintah kabupaten ogan komering ulu
# processing index 477: pemkab ogan ilir
# processing index 478: pemerintah kabupaten ogan ilir
# processing index 479: pemkab ogan komering ulu
# processing index 480: pemerintah kabupaten ogan komering ulu timur
# processing index 481: pemkab ogan komering ulu timur
# processing index 482: pemkab ogan komering ilir
# processing index 483: pemerintah kabupaten ogan komering ulu selatan
# processing index 484: pemkab ogan komering ulu selatan
# processing index 485: pemerintah kabupaten ogan komering ilir
# processing index 486: pemkab pekalongan
# processing index 487: pemerintah kabupaten pekalongan
# processing index 488: pemkab polewali mandar
# processing index 489: pemkab samosir
# processing index 490: pemerintah kabupaten toba samosir
# processing index 491: pemkab toba samosir
# processing index 492: pemerintah kabupaten siak
# processing index 493: pemkab sigi
# processing index 494: pemkab solok selatan
# processing index 495: pemerintah kabupaten sorong
# processing index 496: pemkab sorong
# processing index 497: pemerintah kabupaten sorong selatan
# processing index 498: pemkab sorong selatan
# processing index 499: pemkab solok
# processing index 500: pemerintah kabupaten solok
# processing index 501: pemerintah kabupaten tabanan
# processing index 502: pemkab takalar
# processing index 503: pemerintah kabupaten tana toraja
# processing index 504: pemkab tanah datar
# processing index 505: pemkab tana toraja
# processing index 506: pemkab tapanuli tengah
# processing index 507: pemerintah kabupaten tapanuli utara
# processing index 508: pemkab tapanuli utara
# processing index 509: pemerintah kabupaten tapanuli selatan
# processing index 510: pemkab tapanuli selatan
# processing index 511: pemkab teluk bintuni
# processing index 512: pemerintah kabupaten teluk bintuni
# processing index 513: pemkab teluk wondama
# processing index 514: pemerintah kabupaten sinjai
# processing index 515: pemkab sinjai
# processing index 516: pemkot binjai
# processing index 517: pemerintah kota magelang
# processing index 518: pemkot makassar
# processing index 519: pemerintah kota malang
# processing index 520: pemprov sulawesi barat
# processing index 521: pemerintah provinsi sulawesi tengah
# processing index 522: pemprov sulawesi tengah
# processing index 523: pemerintah provinsi sulawesi tenggara
# processing index 524: pemprov sulawesi tenggara
# processing index 525: pemerintah provinsi sulawesi selatan
# processing index 526: pemprov sulawesi utara
# processing index 527: pemerintah provinsi sumbar
# processing index 528: pemerintah provinsi sulawesi utara
# processing index 529: pemerintah provinsi sulbar
# processing index 530: pemprov sulawesi selatan
# processing index 531: pemprov sumbar
# processing index 532: pemerintah provinsi sulsel
# processing index 533: pemerintah provinsi sumsel
# processing index 534: pemerintah provinsi sulawesi barat
# processing index 535: pemprov sumsel
# processing index 536: pemprov sumatera utara
# processing index 537: pemerintah provinsi sumatera utara
# processing index 538: pemerintah provinsi sumatera selatan
# processing index 539: pemprov sulbar
# processing index 540: pemprov sumatera barat
# processing index 541: pemprov sumatera selatan
# processing index 542: perum pengangkutan penumpang djakarta
# processing index 543: ppd
# processing index 544: pengangkutan penumpang djakarta
# processing index 545: pengangkutan penumpang
# processing index 546: pengangkutan
# processing index 547: penumpang djakarta
# processing index 548: penumpang
# processing index 549: perum pengangkutan penumpang
# processing index 550: pt adhi karya
# processing index 551: adhi karya
# processing index 552: adhi
# processing index 553: karya
# processing index 554: pt adhi
# processing index 555: pt karya
# processing index 556: asuransi jasa indonesia
# processing index 557: pt asuransi jasa indonesia
# processing index 558: asuransi jasa
# processing index 559: asuransi indonesia
# processing index 560: pt asuransi indonesia
# processing index 561: pt asuransi
# processing index 562: pt asuransi jasa
# processing index 563: pt asuransi kredit indonesia
# processing index 564: pt asuransi kredit
# processing index 565: asuransi kredit indonesia
# processing index 566: kredit indonesia
# processing index 567: asuransi kredit
# processing index 568: pt kredit indonesia
# processing index 569: bank mandiri
# processing index 570: pt bank mandiri
# processing index 571: nasabah bank mandiri pemilik toko parfum
# processing index 572: nasabah bank mandiri
# processing index 573: nasabah bank
# processing index 574: nasabah mandiri
# processing index 575: mandiri
# processing index 576: bank
# processing index 577: bank mandiri pematang siantar kcp sutomo
# processing index 578: bank mandiri kcp
# processing index 579: bank mandiri taspen
# processing index 580: taspen
# processing index 581: bank taspen
# processing index 582: pt bank mandiri cabang
# processing index 583: bank cabang
# processing index 584: pt bank cabang
# processing index 585: pt bank mandiri cabang cikampek
# processing index 586: pt bank mandiri cikampek
# processing index 587: bank mandiri cabang samarinda
# processing index 588: pt bank mandiri cabang samarinda
# processing index 589: bank mandiri cabang gunungsari
# processing index 590: pt bina karya
# processing index 591: bina karya
# processing index 592: bina
# processing index 593: pt bina
# processing index 594: bina karya indonesia
# processing index 595: pt bina karya indonesia
# processing index 596: karya indonesia
# processing index 597: bina indonesia
# processing index 598: pt dirgantara indonesia
# processing index 599: pt di
# processing index 600: pt dirgantara
# processing index 601: dirgantara
# processing index 602: pt garam
# processing index 603: garam
# processing index 604: pt hotel indonesia natour
# processing index 605: hotel natour
# processing index 606: pt hotel indonesia
# processing index 607: natour hotel
# processing index 608: natour indonesia
# processing index 609: hotel indonesia
# processing index 610: pt asuransi jasa raharja
# processing index 611: pt jasa raharja
# processing index 612: asuransi jasa raharja
# processing index 613: jasa raharja
# processing index 614: pt jasa
# processing index 615: pt raharja
# processing index 616: pt penerbitan dan percetakan balai pustaka
# processing index 617: pt balai pustaka
# processing index 618: balai pustaka
# processing index 619: penerbitan dan percetakan
# processing index 620: penerbitan
# processing index 621: percetakan
# processing index 622: penerbitan balai pustaka
# processing index 623: percetakan balai pustaka
# processing index 624: balai
# processing index 625: pustaka
# processing index 626: pt perikanan nusantara
# processing index 627: pt perinus
# processing index 628: perikanan nusantara
# processing index 629: perinus
# processing index 630: perikanan indonesia
# processing index 631: pt perikanan
# processing index 632: perikanan
# processing index 633: pt pindad
# processing index 634: pindad
# processing index 635: pt rajawali nusantara indonesia
# processing index 636: rajawali nusantara indonesia
# processing index 637: pt rni
# processing index 638: rni
# processing index 639: id food
# processing index 640: rajawali
# processing index 641: rajawali nusindo
# processing index 642: pt rajawali nusindo
# processing index 643: pt rajawali citra televisi indonesia
# processing index 644: pt rajawali indonesia
# processing index 645: pt sang hyang seri
# processing index 646: sang hyang seri
# processing index 647: pt shs
# processing index 648: shs
# processing index 649: pt sang
# processing index 650: pt seri
# processing index 651: sucofindo
# processing index 652: pt sucofindo
# processing index 653: pt superintending company of indonesia
# processing index 654: superintending company of indonesia
# processing index 655: pt surveyor indonesia
# processing index 656: surveyor indonesia
# processing index 657: surveyor
# processing index 658: ptsi
# processing index 659: pt taman wisata candi borobudur prambanan dan ratu boko
# processing index 660: taman wisata candi borobudur prambanan dan ratu boko
# processing index 661: pt twc
# processing index 662: pt taman wisata candi
# processing index 663: taman wisata candi
# processing index 664: candi borobudur
# processing index 665: candi prambanan
# processing index 666: ratu boko
# processing index 667: borobudur
# processing index 668: prambanan
# processing index 669: pt kereta api indonesia
# processing index 670: kereta api indonesia
# processing index 671: pt kai
# processing index 672: kai
# processing index 673: pt kereta api
# processing index 674: api indonesia
# processing index 675: pt telkom pcc
# processing index 676: pt telekomunikasi indonesia
# processing index 677: pt telkom indonesia tbk
# processing index 678: pt telkom
# processing index 679: telkomsel
# processing index 680: pt telkomsel
# processing index 681: telkom
# processing index 682: telkom indonesia
# processing index 683: pt dok dan perkapalan surabaya dps
# processing index 684: pt dok dan perkapalan surabaya
# processing index 685: dok dan perkapalan surabaya
# processing index 686: pt dps
# processing index 687: perkapalan
# processing index 688: dok dan perkapalan
# processing index 689: perkapalan surabaya
# processing index 690: dok surabaya
# processing index 691: lembaga kantor berita nasional antara biro jawa barat
# processing index 692: perum lkbn antara
# processing index 693: perum pembangunan perumahan nasional perumnas
# processing index 694: kantor perum damri
# processing index 695: perum ppd
# processing index 696: perusahaan umum pengangkutan penumpang djakarta
# processing index 697: dinas perumahan rakyat dan permukiman provinsi dki jakarta
# processing index 698: pt amarta karya persero
# processing index 699: pt karya solusi prima sejahtera
# processing index 700: asuransi jasindo
# processing index 701: pt asuransi jasa raharja persero
# processing index 702: pt asuransi jiwasraya persero
# processing index 703: askrindo
# processing index 704: pt askrindo
# processing index 705: pt asuransi jasa indonesia persero
# processing index 706: bank mandiri cihampelas
# processing index 707: pt sentral utama teknikal mandiri
# processing index 708: pt bank central asia tbk
# processing index 709: bank btn jayapura
# processing index 710: btn pluit
# processing index 711: bank negara indonesia
# processing index 712: pt bank tabungan pensiunan nasional
# processing index 713: bina karya persero
# processing index 714: smk s swa bina karya
# processing index 715: pt bina karya prima
# processing index 716: ptdi
# processing index 717: pt dirgantara yudha artha
# processing index 718: pt garuda indonesia
# processing index 719: pt garam persero
# processing index 720: pt gudang garam tbk
# processing index 721: pt garam nusantara lestari
# processing index 722: pt hin
# processing index 723: inna hotels and resorts
# processing index 724: hotel indonesia kempinski jakarta
# processing index 725: pt inalum
# processing index 726: pt indonesia asahan aluminium persero
# processing index 727: pt daiki aluminium industry indonesia
# processing index 728: pt aluminium karya abadi
# processing index 729: pelindo ii
# processing index 730: pelabuhan indonesia ii
# processing index 731: pelabuhan indonesia
# processing index 732: pelindo
# processing index 733: penerbit dan percetakan mediatama
# processing index 734: pt percetakan gramedia cikarang
# processing index 735: pt ppi
# processing index 736: perusahaan perdagangan indonesia
# processing index 737: kementerian perdagangan republik indonesia
# processing index 738: pt perdagangan mistico indonesia
# processing index 739: pt pal
# processing index 740: pt pinus merah abadi
# processing index 741: pt nusantara laju bersama
# processing index 742: pt sucorinvest asset management
# processing index 743: pt sucor sekuritas
# processing index 744: pt semen indonesia persero
# processing index 745: pt frasta survey indonesia
# processing index 746: taman wisata bougenville
# processing index 747: taman wisata alam sevillage
# processing index 748: indofarma tbk
# processing index 749: indofarma global medika
# processing index 750: indofarma global medika cabang
# processing index 751: pt igm
# processing index 752: indofarma
# processing index 753: igm
# processing index 754: kereta api
# processing index 755: pt perkapalan
# processing index 756: pt dok

# %%
predictions.head()
# Out:
#                            nama_instansi  \
# 0                    kementerian agraria
# 1                 kementerian tata ruang
# 2  kementerian badan pertanahan nasional
# 3              badan pertanahan nasional
# 4                                    atr
#
#                               candidates
# 0                    kementerian agraria
# 1                 kementerian tata ruang
# 2  kementerian badan pertanahan nasional
# 3              badan pertanahan nasional
# 4                                    atr

# %%
predictions
# Out:
#                              nama_instansi  \
# 0                      kementerian agraria
# 1                   kementerian tata ruang
# 2    kementerian badan pertanahan nasional
# 3                badan pertanahan nasional
# 4                                      atr
# ..                                     ...
# 752                              indofarma
# 753                                    igm
# 754                             kereta api
# 755                          pt perkapalan
# 756                                 pt dok
#
#                                 candidates
# 0                      kementerian agraria
# 1                   kementerian tata ruang
# 2    kementerian badan pertanahan nasional
# 3                badan pertanahan nasional
# 4                                      atr
# ..                                     ...
# 752                              indofarma
# 753                                 pt igm
# 754                          pt kereta api
# 755                                 pt pal
# 756                pt telkom indonesia tbk
#
# [757 rows x 2 columns]

# %%
predictions.groupby('candidates').count().sort_values('nama_instansi', ascending=False)
# Out:
#                                                     nama_instansi
# candidates
# Bukan instansi BUMN, Kementerian, Pemerintah                   38
# dok dan perkapalan surabaya                                     5
# taman wisata candi borobudur prambanan dan ratu...              5
# perum pengangkutan penumpang                                    4
# badan pengelola keuangan haji                                   3
# ...                                                           ...
# pemerintah kabupaten seram bagian timur                         1
# pemerintah kabupaten seram barat                                1
# pemerintah kabupaten siak                                       1
# pemerintah kabupaten sinjai                                     1
# telkom indonesia                                                1
#
# [610 rows x 1 columns]

# %% [markdown]
# ## Get true references for each candidate returned

# %%
train = pd.read_csv('../indexing/data/splitted_data/v2/train.csv')
val = pd.read_csv('../indexing/data/splitted_data/v2/val.csv')
test = pd.read_csv('../indexing/data/splitted_data/v2/test.csv')

# %%
df_all = pd.concat([train, val, test])

# %%
df_all.reset_index(drop=True, inplace=True)

# %%
df_all
# Out:
#                                       instansi status  \
# 0          lembaga pembiayaan ekspor indonesia    yes
# 1          lembaga pembiayaan ekspor indonesia    yes
# 2          lembaga pembiayaan ekspor indonesia    yes
# 3          lembaga pembiayaan ekspor indonesia    yes
# 4          lembaga pembiayaan ekspor indonesia     no
# ...                                        ...    ...
# 4340                              pt indofarma    yes
# 4341                              pt indofarma     no
# 4342   pt kereta api indonesia (persero) (kai)     no
# 4343  pt dok dan perkapalan surabaya (persero)     no
# 4344  pt dok dan perkapalan surabaya (persero)     no
#
#                         reference
# 0       lembaga pembiayaan ekspor
# 1                            lpei
# 2        lembaga ekspor indonesia
# 3     pembiayaan ekspor indonesia
# 4            pembiayaan indonesia
# ...                           ...
# 4340                    indofarma
# 4341                          igm
# 4342                   kereta api
# 4343                pt perkapalan
# 4344                       pt dok
#
# [4345 rows x 3 columns]

# %%
df_all['cln_instansi'] = df_all['instansi'].str.replace('/', ' ')
df_all['cln_instansi'] = df_all['cln_instansi'].str.replace('[^\w\s]','',regex=True)

# %%
df_all['cln_reference'] = df_all['reference'].str.replace('/', ' ')
df_all['cln_reference'] = df_all['cln_reference'].str.replace('[^\w\s]','',regex=True)

# %%
df_all = df_all.drop(['reference', 'instansi'], axis=1)
df_all = df_all.rename(columns={'cln_reference':'reference', 'cln_instansi':'instansi'})

# %%
df_all
# Out:
#      status                                instansi  \
# 0       yes     lembaga pembiayaan ekspor indonesia
# 1       yes     lembaga pembiayaan ekspor indonesia
# 2       yes     lembaga pembiayaan ekspor indonesia
# 3       yes     lembaga pembiayaan ekspor indonesia
# 4        no     lembaga pembiayaan ekspor indonesia
# ...     ...                                     ...
# 4340    yes                            pt indofarma
# 4341     no                            pt indofarma
# 4342     no     pt kereta api indonesia persero kai
# 4343     no  pt dok dan perkapalan surabaya persero
# 4344     no  pt dok dan perkapalan surabaya persero
#
#                         reference
# 0       lembaga pembiayaan ekspor
# 1                            lpei
# 2        lembaga ekspor indonesia
# 3     pembiayaan ekspor indonesia
# 4            pembiayaan indonesia
# ...                           ...
# 4340                    indofarma
# 4341                          igm
# 4342                   kereta api
# 4343                pt perkapalan
# 4344                       pt dok
#
# [4345 rows x 3 columns]

# %%
df_all[df_all['instansi'].str.startswith('kementerian agraria dan tata ruang')]['instansi'].iloc[0]
# Out:
# 'kementerian agraria dan tata ruang badan pertanahan nasional bpn'

# %%
def get_official_instansi(nama_instansi):
    official = ''
    try:
        official = df_all[(df_all['reference']==nama_instansi) & (df_all['status']=='yes')]['instansi'].values[0]
    except:
        official = df_all[(df_all['instansi']==nama_instansi)]['instansi'].values[0]
    return official

# %%
get_official_instansi('badan pertanahan nasional')
# Out:
# 'kementerian agraria dan tata ruang badan pertanahan nasional bpn'

# %%
def get_true_references(nama_instansi):
    official_instansi = get_official_instansi(nama_instansi)
    true_refs = [official_instansi]
    true_references = df_all[(df_all['instansi']==official_instansi) & (df_all['status']=='yes')]['reference']
    for i in true_references:
        true_refs.append(i)
    return true_refs

# %%
get_true_references('badan pertanahan nasional')
# Out:
# ['kementerian agraria dan tata ruang badan pertanahan nasional bpn',
#  'kementerian agraria',
#  'kementerian tata ruang',
#  'kementerian badan pertanahan nasional',
#  'badan pertanahan nasional',
#  'atr',
#  'bpn',
#  'atr bpn']

# %% [markdown]
# ### Loop through

# %%
predicted_status = []
true_references = []

# %%
for index, row in predictions.iterrows():
    nama_inst = row[['candidates']].values[0]
    
    try:
        if nama_inst == 'Bukan instansi BUMN, Kementerian, Pemerintah':
            true_references.append([])
            predicted_status.append('True')
        else:
            true_ref = get_true_references(nama_inst)
            true_references.append(true_ref)
            test_instansi = row[['nama_instansi']].values[0]
            if test_instansi in true_ref:
                predicted_status.append('yes')
            else:
                predicted_status.append('no')
    except:
        print(nama_inst)
        print(index)
        predicted_status.append('no')
        true_references.append([])
        continue
# Out:
# kementerian agraria dan tata ruang badan pertahanan nasional bpn
# 8
# kementerian agraria dan tata ruang badan pertahanan nasional bpn
# 51

# %%
predictions['status_from_references'] = predicted_status
predictions['true_references'] = true_references

# %%
predictions
# Out:
#                              nama_instansi  \
# 0                      kementerian agraria
# 1                   kementerian tata ruang
# 2    kementerian badan pertanahan nasional
# 3                badan pertanahan nasional
# 4                                      atr
# ..                                     ...
# 752                              indofarma
# 753                                    igm
# 754                             kereta api
# 755                          pt perkapalan
# 756                                 pt dok
#
#                                 candidates status_from_references  \
# 0                      kementerian agraria                    yes
# 1                   kementerian tata ruang                    yes
# 2    kementerian badan pertanahan nasional                    yes
# 3                badan pertanahan nasional                    yes
# 4                                      atr                    yes
# ..                                     ...                    ...
# 752                              indofarma                    yes
# 753                                 pt igm                     no
# 754                          pt kereta api                     no
# 755                                 pt pal                     no
# 756                pt telkom indonesia tbk                     no
#
#                                        true_references
# 0    [kementerian agraria dan tata ruang badan pert...
# 1    [kementerian agraria dan tata ruang badan pert...
# 2    [kementerian agraria dan tata ruang badan pert...
# 3    [kementerian agraria dan tata ruang badan pert...
# 4    [kementerian agraria dan tata ruang badan pert...
# ..                                                 ...
# 752  [pt indofarma persero tbk, pt indofarma, pt in...
# 753  [pt indofarma, indofarma tbk, indofarma global...
# 754  [pt kereta api indonesia persero kai, pt keret...
# 755  [pt pal indonesia persero, pt pal, pal, pt pal...
# 756  [pt telekomunikasi indonesia persero tbk, pt t...
#
# [757 rows x 4 columns]

# %%
predictions.groupby('status_from_references').count()[['nama_instansi']]
# Out:
#                         nama_instansi
# status_from_references
# no                                166
# yes                               591

# %%
predictions.to_csv('./eval/lev_performances/exp1a-2a.csv')

# %% [markdown]
# ## Manually Checked

# %%
checks_completed = pd.read_csv('./eval/lev_performances/exp1a-2a_checked.csv', sep=';')

# %%
checks_completed
# Out:
#      Column1                          nama_instansi  \
# 0          0                    kementerian agraria
# 1          1                 kementerian tata ruang
# 2          2  kementerian badan pertanahan nasional
# 3          3              badan pertanahan nasional
# 4          4                                    atr
# ..       ...                                    ...
# 752      752                              indofarma
# 753      753                                    igm
# 754      754                             kereta api
# 755      755                          pt perkapalan
# 756      756                                 pt dok
#
#                                 candidates status_manual  \
# 0                      kementerian agraria           yes
# 1                   kementerian tata ruang           yes
# 2    kementerian badan pertanahan nasional           yes
# 3                badan pertanahan nasional           yes
# 4                                      atr           yes
# ..                                     ...           ...
# 752                              indofarma           yes
# 753                                 pt igm           yes
# 754                          pt kereta api            no
# 755                                 pt pal            no
# 756                pt telkom indonesia tbk            no
#
#     status_from_references                                    true_references
# 0                      yes  ['kementerian agraria dan tata ruang badan per...
# 1                      yes  ['kementerian agraria dan tata ruang badan per...
# 2                      yes  ['kementerian agraria dan tata ruang badan per...
# 3                      yes  ['kementerian agraria dan tata ruang badan per...
# 4                      yes  ['kementerian agraria dan tata ruang badan per...
# ..                     ...                                                ...
# 752                    yes  ['pt indofarma persero tbk', 'pt indofarma', '...
# 753                     no  ['pt indofarma', 'indofarma tbk', 'indofarma g...
# 754                     no  ['pt kereta api indonesia persero kai', 'pt ke...
# 755                     no  ['pt pal indonesia persero', 'pt pal', 'pal', ...
# 756                     no  ['pt telekomunikasi indonesia persero tbk', 'p...
#
# [757 rows x 6 columns]

# %% [markdown]
# ## Matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
status_d = {
    'no': 0,
    'yes': 1
}
copied = checks_completed.copy()
copied['status_manual'] = copied['status_manual'].map(status_d)
copied['status_from_references'] = copied['status_from_references'].map(status_d)

# %%
y_true = copied['status_manual']
y_pred = copied['status_from_references']

# %%
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm/np.sum(cm), annot=True, fmt='.2%', cmap='Blues')
plt.xlabel('Status From Reference')
plt.ylabel('Status Manual')
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
agg = checks_completed.groupby('status_manual').count()[['nama_instansi']]

# %%
agg.plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='status_manual'>

# %%
agg
# Out:
#                nama_instansi
# status_manual
# no                       158
# yes                      599

# %%
599/(599+158)
# Out:
# 0.7912813738441216

# %%
tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

# %%
print(tn, fp, fn, tp)
# Out:
# 146 12 20 579
